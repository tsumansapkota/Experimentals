# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
# %matplotlib inline
from tensorflow.examples.tutorials.mnist import input_data

# %%
mnist = input_data.read_data_sets("../../Tensorflow-Bootcamp-master/03-Convolutional-Neural-Networks/MNIST_data/",one_hot=True)
# Out:
# Extracting ../../Tensorflow-Bootcamp-master/03-Convolutional-Neural-Networks/MNIST_data/train-images-idx3-ubyte.gz
# Extracting ../../Tensorflow-Bootcamp-master/03-Convolutional-Neural-Networks/MNIST_data/train-labels-idx1-ubyte.gz
# Extracting ../../Tensorflow-Bootcamp-master/03-Convolutional-Neural-Networks/MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting ../../Tensorflow-Bootcamp-master/03-Convolutional-Neural-Networks/MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
tf.reset_default_graph()

# %%
# DEFINE parameters
num_label = 10
label_hid1 = 5
label_hid2 = 3
label_hid3 = 2
label_hid4 = 1

num_image = 784 # 28*28
image_hid1 = 392
image_hid2 = 196
image_hid3 = 98
image_hid4 = 49
image_hid5 = 25
image_hid6 = 12
image_hid7 = 6
image_hid8 = 3
image_hid9 = 2
image_hid10 = 1

# %%
tie_weight = tf.transpose
act_func = lambda X:X
initializer = tf.variance_scaling_initializer()

# %%
## PLACEHOLDER DEFINATION
X = tf.placeholder(tf.float32, shape=[None, num_image])
Y = tf.placeholder(tf.float32, shape=[None, num_label])

# %% [markdown]
# ## Loading Encoded Model

# %%
## IMAGE COMPRESSION
wi1 = tf.Variable(np.load('../save/weights/w1.npy'))
wi2 = tf.Variable(np.load('../save/weights/w2.npy'))
wi3 = tf.Variable(np.load('../save/weights/w3.npy'))
wi4 = tf.Variable(np.load('../save/weights/w4.npy'))
wi5 = tf.Variable(np.load('../save/weights/w5.npy'))
wi6 = tf.Variable(np.load('../save/weights/w6.npy'))
wi7 = tf.Variable(np.load('../save/weights/w7.npy'))
wi8 = tf.Variable(np.load('../save/weights/w8.npy'))
wi9 = tf.Variable(np.load('../save/weights/w9.npy'))
wi10 = tf.Variable(np.load('../save/weights/w10.npy'))

# %%
img_layer1 = act_func(tf.matmul(X, wi1))
img_layer2 = act_func(tf.matmul(img_layer1, wi2))
img_layer3 = act_func(tf.matmul(img_layer2, wi3))
img_layer4 = act_func(tf.matmul(img_layer3, wi4))
img_layer5 = act_func(tf.matmul(img_layer4, wi5))
img_layer6 = act_func(tf.matmul(img_layer5, wi6))
img_layer7 = act_func(tf.matmul(img_layer6, wi7))
img_layer8 = act_func(tf.matmul(img_layer7, wi8))
img_layer9 = act_func(tf.matmul(img_layer8, wi9))
img_layer10 = act_func(tf.matmul(img_layer9, wi10))

# %%
## LABEL DECOMPRESSION
wl1 = tf.Variable(np.load('../save/weights/lw1.npy'))
wl2 = tf.Variable(np.load('../save/weights/lw2.npy'))
wl3 = tf.Variable(np.load('../save/weights/lw3.npy'))
wl4 = tf.Variable(np.load('../save/weights/lw4.npy'))

# %%
lbl_layer1 = act_func(tf.matmul(Y, wl1))
lbl_layer2 = act_func(tf.matmul(lbl_layer1, wl2))
lbl_layer3 = act_func(tf.matmul(lbl_layer2, wl3))
lbl_layer4 = act_func(tf.matmul(lbl_layer3, wl4))

# %% [markdown]
# ## Setting up learning Model

# %%
# Learning Parameters for activation learning
initializer = tf.random_uniform_initializer()

# input_no = image_hid8
# output_no = label_hid3

inpt = img_layer4
yval = lbl_layer1

i=49
j=3

W1 = tf.Variable(np.load('../save/weights/slearn_parms0_{}-{}.npy'.format(i, j)))
# W1 = tf.Variable(tf.matmul(wi5,pW1))
W2 = tf.Variable(np.load('../save/weights/slearn_parms1_{}-{}.npy'.format(i, j)))
pW3 = tf.Variable(np.load('../save/weights/slearn_parms2_{}-{}.npy'.format(i, j)))
W3 = tf.Variable(tf.matmul(pW3, tf.transpose(wl2)))

b1 = tf.Variable(np.load('../save/weights/slearn_parms3_{}-{}.npy'.format(i, j)))
b2 = tf.Variable(np.load('../save/weights/slearn_parms4_{}-{}.npy'.format(i, j)))
pb3 = tf.Variable(np.load('../save/weights/slearn_parms5_{}-{}.npy'.format(i, j)).reshape(-1,1).T)
b3 = tf.Variable(tf.matmul(pb3,tf.transpose(wl2)))

a1 = tf.nn.relu(tf.matmul(inpt, W1) + b1)
a2 = tf.nn.relu(tf.matmul(a1, W2) + b2)
a3 = tf.matmul(a2, W3) + b3

output = a3

# %%
print(W1)
print(b3)
# Out:
# <tf.Variable 'Variable_21:0' shape=(49, 155) dtype=float32_ref>
# <tf.Variable 'Variable_28:0' shape=(1, 5) dtype=float32_ref>

# %% [markdown]
# ## Create Encode-Decode Model

# %%
# out_layer1 = tf.matmul(output,tf.transpose(wl4))
# out_layer2 = tf.matmul(output,tf.transpose(wl3))
# out_layer3 = tf.matmul(output,tf.transpose(wl2))
out_layer4 = tf.matmul(output,tf.transpose(wl1))

# %%
# LOSS FUNCTIONS
loss = tf.reduce_mean(tf.square(output - yval))
# loss = tf.reduce_mean(tf.abs(output_layer - X))
# cross_entropy = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=Y,logits=yout))

# %%
# TRAINING
learning_rate = 0.001
optimizer = tf.train.AdamOptimizer(learning_rate)
train = optimizer.minimize(loss, var_list=[W1, W2, W3, b1, b2, b3])

# %%
# PREPARATION
init = tf.global_variables_initializer()
saver = tf.train.Saver()

# %%
num_epochs = 100
batch_size = 50

try:
    with tf.Session() as sess:
        sess.run(init)

        # Epoch == Entire Training Set
        for epoch in range(num_epochs):
            num_batches = mnist.train.num_examples // batch_size

            # 150 batch size
            for iteration in range(num_batches):
                X_batch, y_batch = mnist.train.next_batch(batch_size+3*epoch)
                sess.run(train, feed_dict={X: X_batch, Y: y_batch})

            training_loss = loss.eval(feed_dict={X: X_batch, Y: y_batch})   
            print("Epoch {} Complete. Training Loss: {}".format(epoch,training_loss))
            saver.save(sess, "../save/slearn_49-5.ckpt")
            
            matches = tf.equal(tf.argmax(out_layer4, 1), tf.argmax(Y,1))
            acc = tf.reduce_mean(tf.cast(matches, tf.float32))

            print('TEST ACCURACY: ')
            print (sess.run(acc, feed_dict={X:mnist.test.images, Y:mnist.test.labels}))
            if epoch % 5 == 0:
                print('TRAIN ACCURACY: ')
                print (sess.run(acc, feed_dict={X:mnist.train.images, Y:mnist.train.labels}))
            print()
            
except KeyboardInterrupt:
    print('Keyboard Interrupted')
finally:
    print('Finished Training the Model')
# Out:
# Epoch 0 Complete. Training Loss: 0.588528573513031
# TEST ACCURACY:
# 0.9453
# TRAIN ACCURACY:
# 0.9517818
#
# Epoch 1 Complete. Training Loss: 0.6433718800544739
# TEST ACCURACY:
# 0.9498
#
# Epoch 2 Complete. Training Loss: 0.5797947645187378
# TEST ACCURACY:
# 0.9508
#
# Epoch 3 Complete. Training Loss: 0.5952749848365784
# TEST ACCURACY:
# 0.9505
#
# Epoch 4 Complete. Training Loss: 0.5337011814117432
# TEST ACCURACY:
# 0.9512
#
# Epoch 5 Complete. Training Loss: 0.47078782320022583
# TEST ACCURACY:
# 0.9525
# TRAIN ACCURACY:
# 0.9584
#
# Epoch 6 Complete. Training Loss: 0.3478204309940338
# TEST ACCURACY:
# 0.9534
#
# Epoch 7 Complete. Training Loss: 0.3779942989349365
# TEST ACCURACY:
# 0.9544
#
# Epoch 8 Complete. Training Loss: 0.5637248754501343
# TEST ACCURACY:
# 0.9547
#
# Epoch 9 Complete. Training Loss: 0.4015812575817108
# TEST ACCURACY:
# 0.9548
#
# Epoch 10 Complete. Training Loss: 0.2847091853618622
# TEST ACCURACY:
# 0.9548
# TRAIN ACCURACY:
# 0.96098185
#
# Epoch 11 Complete. Training Loss: 0.3157523572444916
# TEST ACCURACY:
# 0.9537
#
# Epoch 12 Complete. Training Loss: 0.28061962127685547
# TEST ACCURACY:
# 0.9544
#
# Epoch 13 Complete. Training Loss: 0.2893460988998413
# TEST ACCURACY:
# 0.9539
#
# Epoch 14 Complete. Training Loss: 0.31523755192756653
# TEST ACCURACY:
# 0.9554
#
# Epoch 15 Complete. Training Loss: 0.25084760785102844
# TEST ACCURACY:
# 0.9556
# TRAIN ACCURACY:
# 0.9633818
#
# Epoch 16 Complete. Training Loss: 0.5344493389129639
# TEST ACCURACY:
# 0.955
#
# Epoch 17 Complete. Training Loss: 0.19713632762432098
# TEST ACCURACY:
# 0.9551
#
# Epoch 18 Complete. Training Loss: 0.2791891098022461
# TEST ACCURACY:
# 0.955
#
# Epoch 19 Complete. Training Loss: 0.4589400887489319
# TEST ACCURACY:
# 0.9561
#
# Epoch 20 Complete. Training Loss: 0.28004342317581177
# TEST ACCURACY:
# 0.9558
# TRAIN ACCURACY:
# 0.96483636
#
# Epoch 21 Complete. Training Loss: 0.23558320105075836
# TEST ACCURACY:
# 0.9556
#
# Epoch 22 Complete. Training Loss: 0.2367802858352661
# TEST ACCURACY:
# 0.9563
#
# Epoch 23 Complete. Training Loss: 0.3178487718105316
# TEST ACCURACY:
# 0.9567
#
# Epoch 24 Complete. Training Loss: 0.3751923739910126
# TEST ACCURACY:
# 0.9562
#
# Epoch 25 Complete. Training Loss: 0.3163289725780487
# TEST ACCURACY:
# 0.9556
# TRAIN ACCURACY:
# 0.9657818
#
# Epoch 26 Complete. Training Loss: 0.4226292073726654
# TEST ACCURACY:
# 0.9549
#
# Epoch 27 Complete. Training Loss: 0.24577228724956512
# TEST ACCURACY:
# 0.9572
#
# Epoch 28 Complete. Training Loss: 0.3612965941429138
# TEST ACCURACY:
# 0.956
#
# Epoch 29 Complete. Training Loss: 0.2665170133113861
# TEST ACCURACY:
# 0.9573
#
# Epoch 30 Complete. Training Loss: 0.28180333971977234
# TEST ACCURACY:
# 0.9563
# TRAIN ACCURACY:
# 0.9658
#
# Epoch 31 Complete. Training Loss: 0.3124348819255829
# TEST ACCURACY:
# 0.9575
#
# Epoch 32 Complete. Training Loss: 0.28716185688972473
# TEST ACCURACY:
# 0.9555
#
# Epoch 33 Complete. Training Loss: 0.19819454848766327
# TEST ACCURACY:
# 0.9566
#
# Epoch 34 Complete. Training Loss: 0.20173582434654236
# TEST ACCURACY:
# 0.9572
#
# Epoch 35 Complete. Training Loss: 0.2427331507205963
# TEST ACCURACY:
# 0.957
# TRAIN ACCURACY:
# 0.96687275
#
# Epoch 36 Complete. Training Loss: 0.16674695909023285
# TEST ACCURACY:
# 0.9557
#
# Epoch 37 Complete. Training Loss: 0.33110490441322327
# TEST ACCURACY:
# 0.9561
#
# Epoch 38 Complete. Training Loss: 0.3154436945915222
# TEST ACCURACY:
# 0.9557
#
# Epoch 39 Complete. Training Loss: 0.19074779748916626
# TEST ACCURACY:
# 0.9554
#
# Epoch 40 Complete. Training Loss: 0.3642279803752899
# TEST ACCURACY:
# 0.9563
# TRAIN ACCURACY:
# 0.9678182
#
# Epoch 41 Complete. Training Loss: 0.23884156346321106
# TEST ACCURACY:
# 0.9555
#
# Epoch 42 Complete. Training Loss: 0.24227365851402283
# TEST ACCURACY:
# 0.9559
#
# Epoch 43 Complete. Training Loss: 0.25673341751098633
# TEST ACCURACY:
# 0.957
#
# Epoch 44 Complete. Training Loss: 0.2992194890975952
# TEST ACCURACY:
# 0.9552
#
# Epoch 45 Complete. Training Loss: 0.2549535036087036
# TEST ACCURACY:
# 0.956
# TRAIN ACCURACY:
# 0.96825457
#
# Epoch 46 Complete. Training Loss: 0.36082449555397034
# TEST ACCURACY:
# 0.9566
#
# Epoch 47 Complete. Training Loss: 0.3607152998447418
# TEST ACCURACY:
# 0.9562
#
# Epoch 48 Complete. Training Loss: 0.23461398482322693
# TEST ACCURACY:
# 0.9567
#
# Epoch 49 Complete. Training Loss: 0.37172433733940125
# TEST ACCURACY:
# 0.9563
#
# Epoch 50 Complete. Training Loss: 0.2294875830411911
# TEST ACCURACY:
# 0.956
# TRAIN ACCURACY:
# 0.9684727
#
# Epoch 51 Complete. Training Loss: 0.2468026578426361
# TEST ACCURACY:
# 0.9561
#
# Epoch 52 Complete. Training Loss: 0.24156399071216583
# TEST ACCURACY:
# 0.9571
#
# Epoch 53 Complete. Training Loss: 0.1998378336429596
# TEST ACCURACY:
# 0.9567
#
# Epoch 54 Complete. Training Loss: 0.1862315684556961
# TEST ACCURACY:
# 0.9564
#
# Epoch 55 Complete. Training Loss: 0.19064247608184814
# TEST ACCURACY:
# 0.956
# TRAIN ACCURACY:
# 0.96861815
#
# Epoch 56 Complete. Training Loss: 0.2725757360458374
# TEST ACCURACY:
# 0.9549
#
# Epoch 57 Complete. Training Loss: 0.27719545364379883
# TEST ACCURACY:
# 0.9558
#
# Epoch 58 Complete. Training Loss: 0.16572199761867523
# TEST ACCURACY:
# 0.9556
#
# Epoch 59 Complete. Training Loss: 0.3178039789199829
# TEST ACCURACY:
# 0.9543
#
# Epoch 60 Complete. Training Loss: 0.2639106214046478
# TEST ACCURACY:
# 0.9544
# TRAIN ACCURACY:
# 0.9689818
#
# Epoch 61 Complete. Training Loss: 0.36150220036506653
# TEST ACCURACY:
# 0.9556
#
# Epoch 62 Complete. Training Loss: 0.18603116273880005
# TEST ACCURACY:
# 0.9551
#
# Epoch 63 Complete. Training Loss: 0.21450060606002808
# TEST ACCURACY:
# 0.9556
#
# Keyboard Interrupted
# Finished Training the Model

# %%
num_test_labels = 10
start_point = 15
with tf.Session() as sess:
    
#     sess.run(init)
    saver.restore(sess,"../save/slearn_49-5.ckpt")
    
    params = sess.run([W1, W2, W3, b1, b2, b3])
    
    matches = tf.equal(tf.argmax(out_layer4, 1), tf.argmax(Y,1))
    acc = tf.reduce_mean(tf.cast(matches, tf.float32))
    
    print('TRAIN ACCURACY: ')
    print (sess.run(acc, feed_dict={X:mnist.train.images, Y:mnist.train.labels}))

    print('TEST ACCURACY: ')
    print (sess.run(acc, feed_dict={X:mnist.test.images, Y:mnist.test.labels}))
    print('\n')
# Out:
# INFO:tensorflow:Restoring parameters from ../save/slearn_49-5.ckpt
# TRAIN ACCURACY:
# 0.9691455
# TEST ACCURACY:
# 0.9556

# %%
params
# Out:
# [array([[-0.00877514, -0.00975327, -0.00470845, ..., -0.19805777,
#          -0.00307505, -0.00999339],
#         [ 0.06935491,  0.0770856 ,  0.03721354, ..., -0.44436243,
#           0.02430391,  0.07898346],
#         [-0.07826239, -0.08698598, -0.04199299, ..., -0.09221333,
#          -0.02742533, -0.08912756],
#         ...,
#         [-0.00871293, -0.00968414, -0.00467506, ...,  0.23600592,
#          -0.00305326, -0.00992255],
#         [-0.07684321, -0.08540858, -0.0412315 , ..., -0.49555868,
#          -0.02692801, -0.08751133],
#         [-0.08923733, -0.09918423, -0.04788178, ...,  0.28287536,
#          -0.03127126, -0.10162614]], dtype=float32),
#  array([[ 0.12928236,  0.00709345,  0.2270143 , ..., -0.11943059,
#           0.70338863,  0.65438473],
#         [ 0.5483187 ,  0.02092948,  0.75045013, ...,  0.6519301 ,
#           0.2481015 , -0.07473479],
#         [ 0.6927793 ,  0.39143902,  0.849975  , ..., -0.02917881,
#           0.7804612 ,  0.8315323 ],
#         ...,
#         [ 1.2848235 , -0.03678494,  0.55509275, ...,  0.92876   ,
#           0.43207636, -0.21895006],
#         [ 0.40146548,  0.82552207,  0.22120453, ...,  0.37094074,
#           0.6960912 ,  0.29183385],
#         [ 0.7315277 ,  0.3760425 ,  0.20362827, ...,  0.39146245,
#           0.6885634 ,  0.46912655]], dtype=float32),
#  array([[-1.66176081e-01, -1.62079513e+00, -5.12955412e-02,
#          -1.09267294e+00, -1.74597514e+00],
#         [ 2.02406836e+00, -1.54240334e+00, -7.73422420e-01,
#          -8.83575380e-01, -6.89695776e-01],
#         [ 3.92281175e-01,  5.90392351e-01,  9.86583233e-01,
#          -1.06381869e+00, -1.78812003e+00],
#         [ 4.10232604e-01, -9.55943704e-01,  4.55617398e-01,
#          -1.30624986e+00, -4.81109709e-01],
#         [-1.57417858e+00,  5.54482698e-01,  6.91933870e-01,
#          -5.19539177e-01,  1.56161630e+00],
#         [-2.95056820e+00,  2.98507780e-01, -7.51652420e-01,
#           2.33799124e+00,  2.35850286e+00],
#         [-2.12420750e+00,  3.05934042e-01, -5.87991357e-01,
#           9.55253899e-01,  1.61323142e+00],
#         [-3.68392205e+00, -5.04649401e+00, -2.03912592e+00,
#           9.70418870e-01, -1.20069480e+00],
#         [ 1.96151280e+00,  2.84215450e+00, -1.75400645e-01,
#           8.48642170e-01,  4.28943062e+00],
#         [ 1.76385367e+00, -1.26675919e-01, -1.86538413e-01,
#           1.55111969e+00,  3.68308067e+00],
#         [ 9.49373543e-01, -3.01945955e-01,  2.79873341e-01,
#          -1.17628467e+00,  1.77085921e-01],
#         [ 4.87162530e-01,  1.19637631e-01,  1.94223017e-01,
#          -9.84177828e-01, -2.10633278e+00],
