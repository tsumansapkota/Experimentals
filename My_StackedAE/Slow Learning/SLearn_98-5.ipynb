# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
# %matplotlib inline
from tensorflow.examples.tutorials.mnist import input_data

# %%
mnist = input_data.read_data_sets("../../Tensorflow-Bootcamp-master/03-Convolutional-Neural-Networks/MNIST_data/",one_hot=True)
# Out:
# Extracting ../../Tensorflow-Bootcamp-master/03-Convolutional-Neural-Networks/MNIST_data/train-images-idx3-ubyte.gz
# Extracting ../../Tensorflow-Bootcamp-master/03-Convolutional-Neural-Networks/MNIST_data/train-labels-idx1-ubyte.gz
# Extracting ../../Tensorflow-Bootcamp-master/03-Convolutional-Neural-Networks/MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting ../../Tensorflow-Bootcamp-master/03-Convolutional-Neural-Networks/MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
tf.reset_default_graph()

# %%
# DEFINE parameters
num_label = 10
label_hid1 = 5
label_hid2 = 3
label_hid3 = 2
label_hid4 = 1

num_image = 784 # 28*28
image_hid1 = 392
image_hid2 = 196
image_hid3 = 98
image_hid4 = 49
image_hid5 = 25
image_hid6 = 12
image_hid7 = 6
image_hid8 = 3
image_hid9 = 2
image_hid10 = 1

# %%
tie_weight = tf.transpose
act_func = lambda X:X
initializer = tf.variance_scaling_initializer()

# %%
## PLACEHOLDER DEFINATION
X = tf.placeholder(tf.float32, shape=[None, num_image])
Y = tf.placeholder(tf.float32, shape=[None, num_label])

# %% [markdown]
# ## Loading Encoded Model

# %%
## IMAGE COMPRESSION
wi1 = tf.Variable(np.load('../save/weights/w1.npy'))
wi2 = tf.Variable(np.load('../save/weights/w2.npy'))
wi3 = tf.Variable(np.load('../save/weights/w3.npy'))
wi4 = tf.Variable(np.load('../save/weights/w4.npy'))
wi5 = tf.Variable(np.load('../save/weights/w5.npy'))
wi6 = tf.Variable(np.load('../save/weights/w6.npy'))
wi7 = tf.Variable(np.load('../save/weights/w7.npy'))
wi8 = tf.Variable(np.load('../save/weights/w8.npy'))
wi9 = tf.Variable(np.load('../save/weights/w9.npy'))
wi10 = tf.Variable(np.load('../save/weights/w10.npy'))

# %%
img_layer1 = act_func(tf.matmul(X, wi1))
img_layer2 = act_func(tf.matmul(img_layer1, wi2))
img_layer3 = act_func(tf.matmul(img_layer2, wi3))
img_layer4 = act_func(tf.matmul(img_layer3, wi4))
img_layer5 = act_func(tf.matmul(img_layer4, wi5))
img_layer6 = act_func(tf.matmul(img_layer5, wi6))
img_layer7 = act_func(tf.matmul(img_layer6, wi7))
img_layer8 = act_func(tf.matmul(img_layer7, wi8))
img_layer9 = act_func(tf.matmul(img_layer8, wi9))
img_layer10 = act_func(tf.matmul(img_layer9, wi10))

# %%
## LABEL DECOMPRESSION
wl1 = tf.Variable(np.load('../save/weights/lw1.npy'))
wl2 = tf.Variable(np.load('../save/weights/lw2.npy'))
wl3 = tf.Variable(np.load('../save/weights/lw3.npy'))
wl4 = tf.Variable(np.load('../save/weights/lw4.npy'))

# %%
lbl_layer1 = act_func(tf.matmul(Y, wl1))
lbl_layer2 = act_func(tf.matmul(lbl_layer1, wl2))
lbl_layer3 = act_func(tf.matmul(lbl_layer2, wl3))
lbl_layer4 = act_func(tf.matmul(lbl_layer3, wl4))

# %% [markdown]
# ## Setting up learning Model

# %%
# Learning Parameters for activation learning
initializer = tf.random_uniform_initializer()

# input_no = image_hid8
# output_no = label_hid3

inpt = img_layer3
yval = lbl_layer1

i=49
j=5

pW1 = tf.Variable(np.load('../save/weights/slearn_parms0_{}-{}.npy'.format(i, j)))
W1 = tf.Variable(tf.matmul(wi4,pW1))
W2 = tf.Variable(np.load('../save/weights/slearn_parms1_{}-{}.npy'.format(i, j)))
W3 = tf.Variable(np.load('../save/weights/slearn_parms2_{}-{}.npy'.format(i, j)))
# W3 = tf.Variable(tf.matmul(pW3, tf.transpose(wl2)))

b1 = tf.Variable(np.load('../save/weights/slearn_parms3_{}-{}.npy'.format(i, j)))
b2 = tf.Variable(np.load('../save/weights/slearn_parms4_{}-{}.npy'.format(i, j)))
b3 = tf.Variable(np.load('../save/weights/slearn_parms5_{}-{}.npy'.format(i, j)))
# b3 = tf.Variable(tf.matmul(pb3,tf.transpose(wl2)))

a1 = tf.nn.relu(tf.matmul(inpt, W1) + b1)
a2 = tf.nn.relu(tf.matmul(a1, W2) + b2)
a3 = tf.matmul(a2, W3) + b3

output = a3

# %%
print(W1)
print(b3)
# Out:
# <tf.Variable 'Variable_15:0' shape=(98, 155) dtype=float32_ref>
# <tf.Variable 'Variable_20:0' shape=(1, 5) dtype=float32_ref>

# %% [markdown]
# ## Create Encode-Decode Model

# %%
# out_layer1 = tf.matmul(output,tf.transpose(wl4))
# out_layer2 = tf.matmul(output,tf.transpose(wl3))
# out_layer3 = tf.matmul(output,tf.transpose(wl2))
out_layer4 = tf.matmul(output,tf.transpose(wl1))

# %%
# LOSS FUNCTIONS
loss = tf.reduce_mean(tf.square(output - yval))
# loss = tf.reduce_mean(tf.abs(output_layer - X))
# cross_entropy = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=Y,logits=yout))

# %%
# TRAINING
learning_rate = 0.001
optimizer = tf.train.AdamOptimizer(learning_rate)
train = optimizer.minimize(loss, var_list=[W1, W2, W3, b1, b2, b3])

# %%
# PREPARATION
init = tf.global_variables_initializer()
saver = tf.train.Saver()

# %%
num_epochs = 100
batch_size = 50

try:
    with tf.Session() as sess:
        sess.run(init)

        # Epoch == Entire Training Set
        for epoch in range(num_epochs):
            num_batches = mnist.train.num_examples // batch_size

            # 150 batch size
            for iteration in range(num_batches):
                X_batch, y_batch = mnist.train.next_batch(batch_size+3*epoch)
                sess.run(train, feed_dict={X: X_batch, Y: y_batch})

            training_loss = loss.eval(feed_dict={X: X_batch, Y: y_batch})   
            print("Epoch {} Complete. Training Loss: {}".format(epoch,training_loss))
            saver.save(sess, "../save/slearn_98-5.ckpt")
            
            matches = tf.equal(tf.argmax(out_layer4, 1), tf.argmax(Y,1))
            acc = tf.reduce_mean(tf.cast(matches, tf.float32))

            print('TEST ACCURACY: ')
            print (sess.run(acc, feed_dict={X:mnist.test.images, Y:mnist.test.labels}))
            if epoch % 5 == 0:
                print('TRAIN ACCURACY: ')
                print (sess.run(acc, feed_dict={X:mnist.train.images, Y:mnist.train.labels}))
            print()
            
except KeyboardInterrupt:
    print('Keyboard Interrupted')
finally:
    print('Finished Training the Model')
# Out:
# Epoch 0 Complete. Training Loss: 0.1040123775601387
# TEST ACCURACY:
# 0.9552
# TRAIN ACCURACY:
# 0.968
#
# Epoch 1 Complete. Training Loss: 0.3837869465351105
# TEST ACCURACY:
# 0.9554
#
# Epoch 2 Complete. Training Loss: 0.33801743388175964
# TEST ACCURACY:
# 0.957
#
# Epoch 3 Complete. Training Loss: 0.22177907824516296
# TEST ACCURACY:
# 0.9575
#
# Epoch 4 Complete. Training Loss: 0.1647765189409256
# TEST ACCURACY:
# 0.9568
#
# Epoch 5 Complete. Training Loss: 0.3479859530925751
# TEST ACCURACY:
# 0.9571
# TRAIN ACCURACY:
# 0.97223634
#
# Epoch 6 Complete. Training Loss: 0.3512571156024933
# TEST ACCURACY:
# 0.9576
#
# Epoch 7 Complete. Training Loss: 0.38260412216186523
# TEST ACCURACY:
# 0.9569
#
# Epoch 8 Complete. Training Loss: 0.1573265939950943
# TEST ACCURACY:
# 0.9588
#
# Epoch 9 Complete. Training Loss: 0.2458449900150299
# TEST ACCURACY:
# 0.9598
#
# Epoch 10 Complete. Training Loss: 0.11550197750329971
# TEST ACCURACY:
# 0.9578
# TRAIN ACCURACY:
# 0.9742909
#
# Epoch 11 Complete. Training Loss: 0.23410506546497345
# TEST ACCURACY:
# 0.9599
#
# Epoch 12 Complete. Training Loss: 0.1366254836320877
# TEST ACCURACY:
# 0.9599
#
# Epoch 13 Complete. Training Loss: 0.3049373924732208
# TEST ACCURACY:
# 0.9599
#
# Epoch 14 Complete. Training Loss: 0.14059005677700043
# TEST ACCURACY:
# 0.96
#
# Epoch 15 Complete. Training Loss: 0.20402880012989044
# TEST ACCURACY:
# 0.9599
# TRAIN ACCURACY:
# 0.97556365
#
# Epoch 16 Complete. Training Loss: 0.30212318897247314
# TEST ACCURACY:
# 0.9606
#
# Epoch 17 Complete. Training Loss: 0.33475562930107117
# TEST ACCURACY:
# 0.9607
#
# Epoch 18 Complete. Training Loss: 0.1739840805530548
# TEST ACCURACY:
# 0.9593
#
# Epoch 19 Complete. Training Loss: 0.21470996737480164
# TEST ACCURACY:
# 0.9595
#
# Epoch 20 Complete. Training Loss: 0.25107795000076294
# TEST ACCURACY:
# 0.9591
# TRAIN ACCURACY:
# 0.9766
#
# Epoch 21 Complete. Training Loss: 0.16606611013412476
# TEST ACCURACY:
# 0.9596
#
# Epoch 22 Complete. Training Loss: 0.27706727385520935
# TEST ACCURACY:
# 0.9595
#
# Epoch 23 Complete. Training Loss: 0.17239555716514587
# TEST ACCURACY:
# 0.9609
#
# Epoch 24 Complete. Training Loss: 0.25701016187667847
# TEST ACCURACY:
# 0.9599
#
# Epoch 25 Complete. Training Loss: 0.18068233132362366
# TEST ACCURACY:
# 0.9602
# TRAIN ACCURACY:
# 0.9777273
#
# Epoch 26 Complete. Training Loss: 0.22014546394348145
# TEST ACCURACY:
# 0.9589
#
# Epoch 27 Complete. Training Loss: 0.3125993609428406
# TEST ACCURACY:
# 0.9593
#
# Epoch 28 Complete. Training Loss: 0.11269877105951309
# TEST ACCURACY:
# 0.961
#
# Epoch 29 Complete. Training Loss: 0.18532632291316986
# TEST ACCURACY:
# 0.9604
#
# Epoch 30 Complete. Training Loss: 0.2611035704612732
# TEST ACCURACY:
# 0.9612
# TRAIN ACCURACY:
# 0.97852725
#
# Epoch 31 Complete. Training Loss: 0.18780188262462616
# TEST ACCURACY:
# 0.96
#
# Epoch 32 Complete. Training Loss: 0.13612528145313263
# TEST ACCURACY:
# 0.9599
#
# Epoch 33 Complete. Training Loss: 0.2446773499250412
# TEST ACCURACY:
# 0.9592
#
# Epoch 34 Complete. Training Loss: 0.2334350198507309
# TEST ACCURACY:
# 0.9586
#
# Epoch 35 Complete. Training Loss: 0.19946591556072235
# TEST ACCURACY:
# 0.9592
# TRAIN ACCURACY:
# 0.97885454
#
# Epoch 36 Complete. Training Loss: 0.11120345443487167
# TEST ACCURACY:
# 0.96
#
# Epoch 37 Complete. Training Loss: 0.23272085189819336
# TEST ACCURACY:
# 0.9594
#
# Epoch 38 Complete. Training Loss: 0.15666070580482483
# TEST ACCURACY:
# 0.9594
#
# Epoch 39 Complete. Training Loss: 0.207547128200531
# TEST ACCURACY:
# 0.9592
#
# Epoch 40 Complete. Training Loss: 0.29085221886634827
# TEST ACCURACY:
# 0.9591
# TRAIN ACCURACY:
# 0.9797818
#
# Epoch 41 Complete. Training Loss: 0.21935677528381348
# TEST ACCURACY:
# 0.9595
#
# Epoch 42 Complete. Training Loss: 0.16467170417308807
# TEST ACCURACY:
# 0.96
#
# Epoch 43 Complete. Training Loss: 0.1199263259768486
# TEST ACCURACY:
# 0.959
#
# Epoch 44 Complete. Training Loss: 0.3411436676979065
# TEST ACCURACY:
# 0.9597
#
# Epoch 45 Complete. Training Loss: 0.1320696473121643
# TEST ACCURACY:
# 0.9593
# TRAIN ACCURACY:
# 0.9798
#
# Epoch 46 Complete. Training Loss: 0.16223879158496857
# TEST ACCURACY:
# 0.9587
#
# Epoch 47 Complete. Training Loss: 0.19552409648895264
# TEST ACCURACY:
# 0.9586
#
# Epoch 48 Complete. Training Loss: 0.14678555727005005
# TEST ACCURACY:
# 0.9584
#
# Epoch 49 Complete. Training Loss: 0.11000093072652817
# TEST ACCURACY:
# 0.9587
#
# Epoch 50 Complete. Training Loss: 0.13297921419143677
# TEST ACCURACY:
# 0.9591
# TRAIN ACCURACY:
# 0.9806909
#
# Epoch 51 Complete. Training Loss: 0.18888066709041595
# TEST ACCURACY:
# 0.959
#
# Epoch 52 Complete. Training Loss: 0.10457014292478561
# TEST ACCURACY:
# 0.9574
#
# Epoch 53 Complete. Training Loss: 0.07836773246526718
# TEST ACCURACY:
# 0.9588
#
# Epoch 54 Complete. Training Loss: 0.1378563791513443
# TEST ACCURACY:
# 0.9585
#
# Epoch 55 Complete. Training Loss: 0.07477640360593796
# TEST ACCURACY:
# 0.9578
# TRAIN ACCURACY:
# 0.9808
#
# Epoch 56 Complete. Training Loss: 0.1607324182987213
# TEST ACCURACY:
# 0.9587
#
# Epoch 57 Complete. Training Loss: 0.10673137754201889
# TEST ACCURACY:
# 0.9587
#
# Epoch 58 Complete. Training Loss: 0.21887953579425812
# TEST ACCURACY:
# 0.9589
#
# Epoch 59 Complete. Training Loss: 0.12408238649368286
# TEST ACCURACY:
# 0.9573
#
# Epoch 60 Complete. Training Loss: 0.128777414560318
# TEST ACCURACY:
# 0.9581
# TRAIN ACCURACY:
# 0.9812545
#
# Epoch 61 Complete. Training Loss: 0.17708706855773926
# TEST ACCURACY:
# 0.9585
#
# Epoch 62 Complete. Training Loss: 0.1166301891207695
# TEST ACCURACY:
# 0.9582
#
# Epoch 63 Complete. Training Loss: 0.06539302319288254
# TEST ACCURACY:
# 0.9575
#
# Epoch 64 Complete. Training Loss: 0.13050222396850586
# TEST ACCURACY:
# 0.9578
#
# Epoch 65 Complete. Training Loss: 0.22918248176574707
# TEST ACCURACY:
# 0.9589
# TRAIN ACCURACY:
# 0.98178184
#
# Epoch 66 Complete. Training Loss: 0.1812313199043274
# TEST ACCURACY:
# 0.9572
#
# Epoch 67 Complete. Training Loss: 0.1260129064321518
# TEST ACCURACY:
# 0.9586
#
# Keyboard Interrupted
# Finished Training the Model

# %%
num_test_labels = 10
start_point = 15
with tf.Session() as sess:
    
#     sess.run(init)
    saver.restore(sess,"../save/slearn_98-5.ckpt")
    
    params = sess.run([W1, W2, W3, b1, b2, b3])
    
    matches = tf.equal(tf.argmax(out_layer4, 1), tf.argmax(Y,1))
    acc = tf.reduce_mean(tf.cast(matches, tf.float32))
    
    print('TRAIN ACCURACY: ')
    print (sess.run(acc, feed_dict={X:mnist.train.images, Y:mnist.train.labels}))

    print('TEST ACCURACY: ')
    print (sess.run(acc, feed_dict={X:mnist.test.images, Y:mnist.test.labels}))
    print('\n')
# Out:
# INFO:tensorflow:Restoring parameters from ../save/slearn_98-5.ckpt
# TRAIN ACCURACY:
# 0.9822364
# TEST ACCURACY:
# 0.9586

# %%
params
# Out:
# [array([[-0.01593915, -0.0177158 , -0.00855241, ..., -0.40823847,
#          -0.00558552, -0.01815197],
#         [ 0.02891367,  0.03213655,  0.01551411, ...,  0.27759176,
#           0.01013216,  0.03292774],
#         [ 0.01407494,  0.01564381,  0.00755213, ..., -0.35521486,
#           0.00493225,  0.01602896],
#         ...,
#         [-0.00336599, -0.00374119, -0.00180608, ..., -0.10879049,
#          -0.00117954, -0.00383328],
#         [-0.08102778, -0.09005962, -0.04347679, ..., -0.4883134 ,
#          -0.0283944 , -0.09227683],
#         [-0.01208736, -0.01343467, -0.00648567, ..., -0.612602  ,
#          -0.00423575, -0.01376543]], dtype=float32),
#  array([[ 0.12928236,  0.00709345,  0.2270143 , ..., -0.11943059,
#           0.70338863,  0.65438473],
#         [ 0.5483187 ,  0.02092948,  0.75045013, ...,  0.6519301 ,
#           0.2481015 , -0.07473479],
#         [ 0.6927793 ,  0.39143902,  0.849975  , ..., -0.02917881,
#           0.7804612 ,  0.8315323 ],
#         ...,
#         [ 1.357685  ,  0.07668889,  0.61299175, ...,  0.98476577,
#           0.29407182, -0.13517684],
#         [ 0.40146548,  0.82552207,  0.22120453, ...,  0.37094074,
#           0.6960912 ,  0.29183385],
#         [ 0.7315277 ,  0.3760425 ,  0.20362827, ...,  0.39146245,
#           0.6885634 ,  0.46912655]], dtype=float32),
#  array([[-0.20032386, -1.6917998 ,  0.22973736, -0.9647765 , -1.6560855 ],
#         [ 2.019933  , -1.3271327 , -1.2055929 , -0.15290962, -0.9320293 ],
#         [ 0.3692444 ,  0.60719895,  1.1667235 , -0.9467748 , -1.733306  ],
#         [ 0.23188046, -1.0084527 ,  0.423254  , -1.401836  , -0.2461161 ],
#         [-1.5681525 ,  0.47056776,  0.7790786 , -0.7895829 ,  1.7998066 ],
#         [-2.8346632 ,  0.36815342, -0.735978  ,  2.1944566 ,  2.5104682 ],
#         [-2.1125522 ,  0.2689269 , -0.41602898,  0.8925103 ,  1.5939791 ],
#         [-3.106532  , -5.493241  , -1.8852223 ,  0.9709044 , -1.096092  ],
