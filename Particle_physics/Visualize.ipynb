# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('./clean_element.csv')

# %%
df
# Out:
#      Unnamed: 0   SN symbol            name  atomicNumber  proton  neutron  \
# 0             0    1     H         Hydrogen             1       1        0
# 1             1    2    He           Helium             2       2        2
# 2             2    3    Li          Lithium             3       3        4
# 3             3    4    Be        Beryllium             4       4        5
# 4             4    5     B            Boron             5       5        6
# 5             5    6     C           Carbon             6       6        6
# 6             6    7     N         Nitrogen             7       7        7
# 7             7    8     O           Oxygen             8       8        8
# 8             8    9     F         Fluorine             9       9       10
# 9             9   10    Ne             Neon            10      10       10
# 10           10   11    Na           Sodium            11      11       12
# ...

# %%
plt.plot(df[['proton']].values)
plt.plot(df[['neutron']].values)
