# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
# %matplotlib inline
from tensorflow.examples.tutorials.mnist import input_data

# %%
mnist = input_data.read_data_sets("../../Tensorflow-Bootcamp-master/03-Convolutional-Neural-Networks/MNIST_data/",one_hot=True)
# Out:
# Extracting ../../Tensorflow-Bootcamp-master/03-Convolutional-Neural-Networks/MNIST_data/train-images-idx3-ubyte.gz
# Extracting ../../Tensorflow-Bootcamp-master/03-Convolutional-Neural-Networks/MNIST_data/train-labels-idx1-ubyte.gz
# Extracting ../../Tensorflow-Bootcamp-master/03-Convolutional-Neural-Networks/MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting ../../Tensorflow-Bootcamp-master/03-Convolutional-Neural-Networks/MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
tf.reset_default_graph()

# %%
# DEFINE parameters
num_label = 10
label_hid1 = 5
label_hid2 = 3
label_hid3 = 2
label_hid4 = 1

num_image = 784 # 28*28
image_hid1 = 392
image_hid2 = 196
image_hid3 = 98
image_hid4 = 49
image_hid5 = 25
image_hid6 = 12
image_hid7 = 6
image_hid8 = 3
image_hid9 = 2
image_hid10 = 1

# %%
tie_weight = tf.transpose
act_func = lambda X:X
initializer = tf.variance_scaling_initializer()

# %%
## PLACEHOLDER DEFINATION
X = tf.placeholder(tf.float32, shape=[None, num_image])
Y = tf.placeholder(tf.float32, shape=[None, num_label])

# %% [markdown]
# ## Loading Encoded Model

# %%
## IMAGE COMPRESSION
wi1 = tf.Variable(np.load('../save/weights/w1.npy'))
wi2 = tf.Variable(np.load('../save/weights/w2.npy'))
wi3 = tf.Variable(np.load('../save/weights/w3.npy'))
wi4 = tf.Variable(np.load('../save/weights/w4.npy'))
wi5 = tf.Variable(np.load('../save/weights/w5.npy'))
wi6 = tf.Variable(np.load('../save/weights/w6.npy'))
wi7 = tf.Variable(np.load('../save/weights/w7.npy'))
wi8 = tf.Variable(np.load('../save/weights/w8.npy'))
wi9 = tf.Variable(np.load('../save/weights/w9.npy'))
wi10 = tf.Variable(np.load('../save/weights/w10.npy'))

# %%
img_layer1 = act_func(tf.matmul(X, wi1))
img_layer2 = act_func(tf.matmul(img_layer1, wi2))
img_layer3 = act_func(tf.matmul(img_layer2, wi3))
img_layer4 = act_func(tf.matmul(img_layer3, wi4))
img_layer5 = act_func(tf.matmul(img_layer4, wi5))
img_layer6 = act_func(tf.matmul(img_layer5, wi6))
img_layer7 = act_func(tf.matmul(img_layer6, wi7))
img_layer8 = act_func(tf.matmul(img_layer7, wi8))
img_layer9 = act_func(tf.matmul(img_layer8, wi9))
img_layer10 = act_func(tf.matmul(img_layer9, wi10))

# %%
## LABEL DECOMPRESSION
wl1 = tf.Variable(np.load('../save/weights/lw1.npy'))
wl2 = tf.Variable(np.load('../save/weights/lw2.npy'))
wl3 = tf.Variable(np.load('../save/weights/lw3.npy'))
wl4 = tf.Variable(np.load('../save/weights/lw4.npy'))

# %%
lbl_layer1 = act_func(tf.matmul(Y, wl1))
lbl_layer2 = act_func(tf.matmul(lbl_layer1, wl2))
lbl_layer3 = act_func(tf.matmul(lbl_layer2, wl3))
lbl_layer4 = act_func(tf.matmul(lbl_layer3, wl4))

# %% [markdown]
# ## Setting up learning Model

# %%
# Learning Parameters for activation learning
initializer = tf.random_uniform_initializer()

# input_no = image_hid8
# output_no = label_hid3

inpt = img_layer6
yval = lbl_layer2

i=6
j=3

pW1 = tf.Variable(np.load('../save/weights/slearn_parms0_{}-{}.npy'.format(i, j)))
W1 = tf.Variable(tf.matmul(wi7,pW1))
W2 = tf.Variable(np.load('../save/weights/slearn_parms1_{}-{}.npy'.format(i, j)))
W3 = tf.Variable(np.load('../save/weights/slearn_parms2_{}-{}.npy'.format(i, j)))
# W3 = tf.Variable(tf.matmul(pW3, tf.transpose(wl3)))

b1 = tf.Variable(np.load('../save/weights/slearn_parms3_{}-{}.npy'.format(i, j)))
b2 = tf.Variable(np.load('../save/weights/slearn_parms4_{}-{}.npy'.format(i, j)))
b3 = tf.Variable(np.load('../save/weights/slearn_parms5_{}-{}.npy'.format(i, j)))
# b3 = tf.Variable(tf.matmul(pb3,tf.transpose(wl3)))

a1 = tf.nn.relu(tf.matmul(inpt, W1) + b1)
a2 = tf.nn.relu(tf.matmul(a1, W2) + b2)
a3 = tf.matmul(a2, W3) + b3

output = a3

# %%
print(W1)
print(b3)
# Out:
# <tf.Variable 'Variable_15:0' shape=(12, 155) dtype=float32_ref>
# <tf.Variable 'Variable_20:0' shape=(1, 3) dtype=float32_ref>

# %% [markdown]
# ## Create Encode-Decode Model

# %%
# out_layer1 = tf.matmul(output,tf.transpose(wl4))
# out_layer2 = tf.matmul(output,tf.transpose(wl3))
out_layer3 = tf.matmul(output,tf.transpose(wl2))
out_layer4 = tf.matmul(out_layer3,tf.transpose(wl1))

# %%
# LOSS FUNCTIONS
loss = tf.reduce_mean(tf.square(output - yval))
# loss = tf.reduce_mean(tf.abs(output_layer - X))
# cross_entropy = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=Y,logits=yout))

# %%
# TRAINING
learning_rate = 0.001
optimizer = tf.train.AdamOptimizer(learning_rate)
train = optimizer.minimize(loss, var_list=[W1, W2, W3, b1, b2, b3])

# %%
# PREPARATION
init = tf.global_variables_initializer()
saver = tf.train.Saver()

# %%
num_epochs = 100
batch_size = 50

try:
    with tf.Session() as sess:
        sess.run(init)

        # Epoch == Entire Training Set
        for epoch in range(num_epochs):
            num_batches = mnist.train.num_examples // batch_size

            # 150 batch size
            for iteration in range(num_batches):
                X_batch, y_batch = mnist.train.next_batch(batch_size+3*epoch)
                sess.run(train, feed_dict={X: X_batch, Y: y_batch})

            training_loss = loss.eval(feed_dict={X: X_batch, Y: y_batch})   
            print("Epoch {} Complete. Training Loss: {}".format(epoch,training_loss))
            saver.save(sess, "../save/slearn_12-3.ckpt")
            
            matches = tf.equal(tf.argmax(out_layer4, 1), tf.argmax(Y,1))
            acc = tf.reduce_mean(tf.cast(matches, tf.float32))

            print('TEST ACCURACY: ')
            print (sess.run(acc, feed_dict={X:mnist.test.images, Y:mnist.test.labels}))
            if epoch % 5 == 0:
                print('TRAIN ACCURACY: ')
                print (sess.run(acc, feed_dict={X:mnist.train.images, Y:mnist.train.labels}))
            print()
            
except KeyboardInterrupt:
    print('Keyboard Interrupted')
finally:
    print('Finished Training the Model')
# Out:
# Epoch 0 Complete. Training Loss: 1.0724247694015503
# TEST ACCURACY:
# 0.8297
# TRAIN ACCURACY:
# 0.8277636
#
# Epoch 1 Complete. Training Loss: 2.6263067722320557
# TEST ACCURACY:
# 0.8388
#
# Epoch 2 Complete. Training Loss: 2.1904211044311523
# TEST ACCURACY:
# 0.8466
#
# Epoch 3 Complete. Training Loss: 2.290872097015381
# TEST ACCURACY:
# 0.8538
#
# Epoch 4 Complete. Training Loss: 2.2311506271362305
# TEST ACCURACY:
# 0.856
#
# Epoch 5 Complete. Training Loss: 2.553701400756836
# TEST ACCURACY:
# 0.8586
# TRAIN ACCURACY:
# 0.85876364
#
# Epoch 6 Complete. Training Loss: 1.7446115016937256
# TEST ACCURACY:
# 0.8606
#
# Epoch 7 Complete. Training Loss: 1.653965711593628
# TEST ACCURACY:
# 0.8668
#
# Epoch 8 Complete. Training Loss: 2.240424871444702
# TEST ACCURACY:
# 0.8685
#
# Epoch 9 Complete. Training Loss: 2.287135601043701
# TEST ACCURACY:
# 0.8673
#
# Epoch 10 Complete. Training Loss: 1.1179230213165283
# TEST ACCURACY:
# 0.8677
# TRAIN ACCURACY:
# 0.8694364
#
# Epoch 11 Complete. Training Loss: 2.1048319339752197
# TEST ACCURACY:
# 0.8676
#
# Epoch 12 Complete. Training Loss: 2.483889102935791
# TEST ACCURACY:
# 0.8738
#
# Epoch 13 Complete. Training Loss: 1.5542818307876587
# TEST ACCURACY:
# 0.8732
#
# Epoch 14 Complete. Training Loss: 1.3680757284164429
# TEST ACCURACY:
# 0.8738
#
# Epoch 15 Complete. Training Loss: 1.4175546169281006
# TEST ACCURACY:
# 0.8745
# TRAIN ACCURACY:
# 0.8765636
#
# Epoch 16 Complete. Training Loss: 1.7501850128173828
# TEST ACCURACY:
# 0.8748
#
# Epoch 17 Complete. Training Loss: 1.2876262664794922
# TEST ACCURACY:
# 0.8712
#
# Epoch 18 Complete. Training Loss: 1.3021695613861084
# TEST ACCURACY:
# 0.8761
#
# Epoch 19 Complete. Training Loss: 1.6151248216629028
# TEST ACCURACY:
# 0.875
#
# Epoch 20 Complete. Training Loss: 1.5294615030288696
# TEST ACCURACY:
# 0.8768
# TRAIN ACCURACY:
# 0.87856364
#
# Epoch 21 Complete. Training Loss: 1.0795263051986694
# TEST ACCURACY:
# 0.8799
#
# Epoch 22 Complete. Training Loss: 1.8422232866287231
# TEST ACCURACY:
# 0.8804
#
# Epoch 23 Complete. Training Loss: 2.3092684745788574
# TEST ACCURACY:
# 0.8798
#
# Epoch 24 Complete. Training Loss: 2.0824015140533447
# TEST ACCURACY:
# 0.8812
#
# Epoch 25 Complete. Training Loss: 1.7864028215408325
# TEST ACCURACY:
# 0.8792
# TRAIN ACCURACY:
# 0.8820182
#
# Epoch 26 Complete. Training Loss: 1.9898229837417603
# TEST ACCURACY:
# 0.8795
#
# Epoch 27 Complete. Training Loss: 1.5218414068222046
# TEST ACCURACY:
# 0.8824
#
# Epoch 28 Complete. Training Loss: 1.7121305465698242
# TEST ACCURACY:
# 0.8811
#
# Epoch 29 Complete. Training Loss: 1.1853947639465332
# TEST ACCURACY:
# 0.8816
#
# Epoch 30 Complete. Training Loss: 1.4796062707901
# TEST ACCURACY:
# 0.8828
# TRAIN ACCURACY:
# 0.8856182
#
# Epoch 31 Complete. Training Loss: 1.805226445198059
# TEST ACCURACY:
# 0.8831
#
# Epoch 32 Complete. Training Loss: 1.5623135566711426
# TEST ACCURACY:
# 0.8843
#
# Epoch 33 Complete. Training Loss: 1.5536277294158936
# TEST ACCURACY:
# 0.8861
#
# Epoch 34 Complete. Training Loss: 2.052640199661255
# TEST ACCURACY:
# 0.8863
#
# Epoch 35 Complete. Training Loss: 1.871471881866455
# TEST ACCURACY:
# 0.8855
# TRAIN ACCURACY:
# 0.8873818
#
# Epoch 36 Complete. Training Loss: 1.2711067199707031
# TEST ACCURACY:
# 0.8866
#
# Epoch 37 Complete. Training Loss: 1.5769165754318237
# TEST ACCURACY:
# 0.8868
#
# Epoch 38 Complete. Training Loss: 1.6658827066421509
# TEST ACCURACY:
# 0.8848
#
# Epoch 39 Complete. Training Loss: 1.9749441146850586
# TEST ACCURACY:
# 0.884
#
# Epoch 40 Complete. Training Loss: 1.9668002128601074
# TEST ACCURACY:
# 0.8861
# TRAIN ACCURACY:
# 0.8898909
#
# Epoch 41 Complete. Training Loss: 1.5121620893478394
# TEST ACCURACY:
# 0.8863
#
# Epoch 42 Complete. Training Loss: 1.8916665315628052
# TEST ACCURACY:
# 0.8867
#
# Epoch 43 Complete. Training Loss: 1.652740716934204
# TEST ACCURACY:
# 0.8873
#
# Epoch 44 Complete. Training Loss: 1.9601024389266968
# TEST ACCURACY:
# 0.8881
#
# Epoch 45 Complete. Training Loss: 1.5509119033813477
# TEST ACCURACY:
# 0.8885
# TRAIN ACCURACY:
# 0.8915455
#
# Epoch 46 Complete. Training Loss: 1.3782830238342285
# TEST ACCURACY:
# 0.89
#
# Epoch 47 Complete. Training Loss: 1.799574375152588
# TEST ACCURACY:
# 0.8883
#
# Epoch 48 Complete. Training Loss: 1.5985629558563232
# TEST ACCURACY:
# 0.889
#
# Epoch 49 Complete. Training Loss: 1.2492470741271973
# TEST ACCURACY:
# 0.8915
#
# Keyboard Interrupted
# Finished Training the Model

# %%
num_test_labels = 10
start_point = 15
with tf.Session() as sess:
    
#     sess.run(init)
    saver.restore(sess,"../save/slearn_12-3.ckpt")
    
    params = sess.run([W1, W2, W3, b1, b2, b3])
    
    matches = tf.equal(tf.argmax(out_layer4, 1), tf.argmax(Y,1))
    acc = tf.reduce_mean(tf.cast(matches, tf.float32))
    
    print('TRAIN ACCURACY: ')
    print (sess.run(acc, feed_dict={X:mnist.train.images, Y:mnist.train.labels}))

    print('TEST ACCURACY: ')
    print (sess.run(acc, feed_dict={X:mnist.test.images, Y:mnist.test.labels}))
    print('\n')
# Out:
# INFO:tensorflow:Restoring parameters from ../save/slearn_12-3.ckpt
# TRAIN ACCURACY:
# 0.8944
# TEST ACCURACY:
# 0.8915

# %%
params
# Out:
# [array([[ 0.1177447 ,  0.13086921,  0.06317787, ..., -0.08444633,
#           0.04126104,  0.13409117],
#         [ 0.00120752,  0.00134211,  0.00064792, ...,  0.1985454 ,
#           0.00042315,  0.00137515],
#         [-0.15453504, -0.1717604 , -0.08291835, ...,  0.01268517,
#          -0.0541534 , -0.1759891 ],
#         ...,
#         [-0.11953542, -0.1328595 , -0.06413871, ...,  0.04491833,
#          -0.04188855, -0.13613048],
#         [-0.03415482, -0.0379619 , -0.01832633, ..., -0.35201132,
#          -0.0119688 , -0.03889652],
#         [-0.09162441, -0.10183737, -0.0491626 , ..., -0.2330467 ,
#          -0.03210775, -0.1043446 ]], dtype=float32),
#  array([[ 0.12928236,  0.00709345,  0.2270143 , ..., -0.11943059,
#           0.70338863,  0.65438473],
#         [ 0.5483187 ,  0.02092948,  0.75045013, ...,  0.6519301 ,
#           0.2481015 , -0.07473479],
#         [ 0.6927793 ,  0.39143902,  0.849975  , ..., -0.02917881,
#           0.7804612 ,  0.8315323 ],
#         ...,
#         [ 0.81163144, -0.93861705,  0.3104799 , ...,  0.39340657,
#           0.21180767, -0.09541335],
#         [ 0.40146548,  0.82552207,  0.22120453, ...,  0.37094074,
#           0.6960912 ,  0.29183385],
#         [ 0.7315277 ,  0.3760425 ,  0.20362827, ...,  0.39146245,
#           0.6885634 ,  0.46912655]], dtype=float32),
#  array([[ 0.10448069,  0.20698018,  1.5182574 ],
#         [-1.3847598 ,  0.99886   ,  1.119803  ],
#         [ 0.36854234,  1.2589663 ,  0.6825322 ],
#         [-0.08810956,  0.6727759 ,  0.8275262 ],
#         [-0.22742675, -0.7651102 , -0.9932768 ],
#         [ 1.3436984 , -2.3749914 , -1.6061453 ],
#         [ 0.5079117 , -1.4331942 , -0.82911164],
#         [ 1.2058303 , -2.674672  ,  2.029648  ],
#         [-0.13143513, -0.36749366, -2.7588732 ],
#         [-1.4235874 , -0.5664027 , -1.9065025 ],
#         [-0.84837323,  0.26469368,  0.40855798],
#         [-0.01657634,  1.0325193 ,  1.04183   ],
#         [-0.03270625,  0.87355125,  0.5784423 ],
#         [-0.9415074 ,  1.2083992 ,  1.1543838 ],
#         [-0.3759088 ,  1.3580861 ,  0.4176876 ],
#         [ 1.1156607 ,  0.4592809 , -0.24989322],
#         [ 1.6919224 ,  1.0294207 ,  1.849512  ],
#         [ 0.03716882,  0.50416195,  0.33472338],
#         [ 0.10088008,  1.185179  ,  0.64533186],
#         [-0.73773474,  1.0070784 , -0.26557636],
#         [-0.15200813, -2.0207984 , -2.1116543 ],
#         [-0.6448138 ,  2.6550562 , -0.18728442],
#         [ 0.21984276, -1.052688  , -1.9879714 ],
#         [ 0.72967863, -1.5253732 , -0.84929585],
#         [ 0.21605511,  0.61947095,  0.3875157 ],
#         [ 0.5222159 ,  0.8091283 ,  1.3592945 ],
#         [ 0.98704505, -0.45378965, -1.4338272 ],
#         [-0.5140344 ,  0.97662514,  0.83749455],
#         [-1.9230751 ,  0.45289728,  0.9561448 ],
#         [-0.25573465, -0.9286691 , -1.5242172 ],
#         [-0.8334046 ,  0.05447835,  0.5741978 ]], dtype=float32),
#  array([-0.28383029, -0.31458557, -0.15186486,  0.8464436 , -0.26639026,
#          0.79745483,  0.5562351 , -0.03149702, -0.00305842, -0.5518121 ,
#          0.13541721, -0.21263544, -0.06160916, -0.31217527, -0.10744675,
#          0.84056914, -0.12664579, -0.06842119, -0.04330331, -0.08283355,
#         -0.23805155, -0.1870908 , -0.23751526, -0.3471313 , -0.21489719,
#         -0.18942702, -0.38137606, -0.51963603,  0.05194964, -0.02596493,
#         -0.83263475, -0.33435127, -0.15995553, -0.20170794, -0.14258547,
#         -0.01627403, -0.10622326, -0.08091658, -0.3327444 ,  0.5747949 ,
#         -0.06249094, -0.20345554, -0.00187809, -0.10168617, -0.10713416,
#         -0.32413107, -0.04729197, -0.11250894, -0.19976912, -0.28495467,
#         -0.17469911, -0.30920935,  0.64813   ,  0.43096375, -0.13741975,
#         -0.07063854, -0.16984136, -0.18727449, -0.30248228, -0.7105544 ,
#         -0.23112178, -0.5002493 , -0.19898465, -0.23572895, -0.23653843,
#         -0.27749056, -0.33645573,  0.47919613, -0.31371927, -0.30730048,
#          0.03483503, -0.34579587, -0.23848681, -0.1865959 , -0.09067887,
#         -0.01844228, -0.18869911, -0.21522495,  0.29200387,  0.55056536,
#         -0.19297187, -0.13239871, -1.159229  , -0.19007044, -0.25604025,
#         -0.32444695, -0.2393859 , -0.16607864, -0.18790606, -0.24759218,
#         -0.01826485, -0.31940347, -0.25278816, -0.10948997, -0.3839517 ,
#         -0.17285003, -0.00264572, -0.14541171, -0.31624797, -0.72516084,
#         -0.00314215, -0.11497195, -0.06430664, -0.5516999 , -0.17002307,
#          0.8904198 ,  0.00936649, -0.26094735, -0.10315148, -0.06065961,
#         -0.17272714, -0.12804289, -0.17049542, -0.13507186, -0.13124591,
#         -0.1603494 , -0.75813   , -0.292743  , -0.22242357, -0.18614395,
#         -0.25848284, -0.21713065, -0.6216535 ,  1.3408258 , -0.17476822,
#         -0.0395139 ,  0.04845734, -0.1089573 , -0.21143371, -0.23421483,
#         -0.15427087, -0.13839707,  0.13148999, -0.08271152, -0.04803753,
#         -0.02969478, -0.16844337, -0.12841488,  0.41342208, -0.30410913,
#         -0.20056294, -0.20006253, -0.18251912,  0.11210488, -0.15121455,
#         -0.30812535, -0.22134608, -0.21894099, -0.05538424, -0.31525296,
#         -0.08532681, -0.03395198,  0.09265522, -0.09930573, -0.32260868],
#        dtype=float32),
#  array([-0.08141216,  0.06816274, -0.8416245 ,  0.512613  ,  0.69038296,
#         -0.7349317 ,  1.4387246 , -1.1927273 , -0.14297035, -1.0814792 ,
#          0.12889118, -0.09177125, -0.01531296,  0.3409325 , -0.18218264,
#          0.79527295, -2.1352963 ,  0.08426767, -1.0343457 ,  0.62488216,
#         -1.5534871 ,  0.05314349, -2.0773354 ,  1.3546976 ,  0.11186387,
#          0.47174537,  0.414268  , -0.8807336 ,  0.9249415 , -0.21781585,
#          0.14225444], dtype=float32),
#  array([[ 0.33268735, -1.572735  , -1.8463298 ]], dtype=float32)]

# %%
for i in range(len(params)):
    np.save('../save/weights/slearn_parms{}_12-3.npy'.format(i),params[i])
