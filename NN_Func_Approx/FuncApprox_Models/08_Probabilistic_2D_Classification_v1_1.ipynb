# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
import matplotlib

# %%
def twospirals(n_points, noise=.5):
    """
     Returns the two spirals dataset.
    """
    n = np.sqrt(np.random.rand(n_points,1)) * 780 * (2*np.pi)/360
    d1x = -np.cos(n)*n + np.random.rand(n_points,1) * noise
    d1y = np.sin(n)*n + np.random.rand(n_points,1) * noise
    return (np.vstack((np.hstack((d1x,d1y)),np.hstack((-d1x,-d1y)))), 
            np.hstack((np.zeros(n_points),np.ones(n_points))))

x, y = twospirals(400)
x, y = x/10, y.reshape(-1)
xx, yy = torch.FloatTensor(x), torch.LongTensor(y)
print(x.shape, y.shape)
# %matplotlib inline
plt.scatter(x[:,0], x[:, 1], c=y.reshape(-1))
# Out:
# (800, 2) (800,)

# %%
## creating a probabilistic layer module
class ProbLayer(nn.Module):
    def __init__(self, in_features, out_features, n_probs=2):
        super().__init__()
        self.in_features = in_features
        self.out_features = out_features
        self.n_probs = n_probs
        
        self.fcp = nn.Linear(in_features, n_probs*out_features)
        self.fcr = nn.Linear(in_features, n_probs*out_features)
        self.actf = lambda x:torch.exp(- x**2)
        
    def forward(self,x):
        p = self.actf(self.fcp(x))
        r = self.fcr(x)
        
        out = (p*r).reshape(-1,self.out_features, self.n_probs)
        out = out.sum(dim=-1)
        return out

# %%
## defining the model
class ProbClassification(nn.Module):
    
    def __init__(self, n_hidden=4):
        super().__init__()
        self.pl1 = ProbLayer(2,2, n_hidden)
        self.softmax = nn.Softmax(dim=1)
    
        
    def forward(self,x):
        out = self.pl1(x)
        out = self.softmax(out)
        return out

## defining the model
class MLPClassification(nn.Module):
    
    def __init__(self, n_hidden=4):
        super().__init__()
        self.fc1 = nn.Linear(2,n_hidden)
        self.actf = nn.ReLU()
        self.fc2 = nn.Linear(n_hidden, 2)
        self.softmax = nn.Softmax(dim=1)
    
        
    def forward(self,x):
        h = self.actf(self.fc1(x))
        out = self.fc2(h)
        out = self.softmax(out)
        return out
    
model = ProbClassification(n_hidden=7)
# model = MLPClassification(n_hidden=20)

optimizer = torch.optim.Adam(model.parameters(), lr=0.003)
# optimizer = torch.optim.SGD(model.parameters(), lr=1)
criterion = nn.CrossEntropyLoss()

# %%
# %matplotlib tk
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

plt.ion()
fig.show()
fig.canvas.draw()

EPOCHS = 100000
for step in range(EPOCHS):

    yout = model(xx)
#     print(yout.shape, yy.shape)
    loss = criterion(yout, yy)
    
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    if step % 100 == 0:

        print('_______________________')
        print("epoch", step)
        print("Loss", loss.data)
        
        out = torch.argmax(yout, dim=1)

        ax.clear()
        plt.scatter(x[:,0], x[:, 1], c=out.data.numpy().reshape(-1))       
        fig.canvas.draw()
        plt.pause(0.01)
        print()
        if loss < 0.001:
            print('fitted to our expectation')
            break
# Out:
# _______________________
# epoch 0
# Loss tensor(0.7561)
#
# _______________________
# epoch 100
# Loss tensor(0.6628)
#
# _______________________
# epoch 200
# Loss tensor(0.6492)
#
# _______________________
# epoch 300
# Loss tensor(0.6401)
#
# _______________________
# epoch 400
# Loss tensor(0.6315)
#
# _______________________
# epoch 500
# Loss tensor(0.6220)
#
# _______________________
# epoch 600
# Loss tensor(0.6112)
#
# _______________________
# epoch 700
# Loss tensor(0.5987)
#
# _______________________
# epoch 800
# Loss tensor(0.5848)
#
# _______________________
# epoch 900
# Loss tensor(0.5682)
#
# _______________________
# epoch 1000
# Loss tensor(0.5535)
#
# _______________________
# epoch 1100
# Loss tensor(0.5364)
#
# _______________________
# epoch 1200
# Loss tensor(0.5120)
#
# _______________________
# epoch 1300
# Loss tensor(0.4933)
#
# _______________________
# epoch 1400
# Loss tensor(0.4766)
#
# _______________________
# epoch 1500
# Loss tensor(0.4599)
#
# _______________________
# epoch 1600
# Loss tensor(0.4481)
#
# _______________________
# epoch 1700
# Loss tensor(0.4403)
#
# _______________________
# epoch 1800
# Loss tensor(0.4343)
#
# _______________________
# epoch 1900
# Loss tensor(0.4296)
#
# _______________________
# epoch 2000
# Loss tensor(0.4255)
#
# _______________________
# epoch 2100
# Loss tensor(0.4220)
#
# _______________________
# epoch 2200
# Loss tensor(0.4188)
#
# _______________________
# epoch 2300
# Loss tensor(0.4158)
#
# _______________________
# epoch 2400
# Loss tensor(0.4091)
#
# _______________________
# epoch 2500
# Loss tensor(0.3993)
#
# _______________________
# epoch 2600
# Loss tensor(0.3930)
#
# _______________________
# epoch 2700
# Loss tensor(0.3870)
#
# _______________________
# epoch 2800
# Loss tensor(0.3830)
#
# _______________________
# epoch 2900
# Loss tensor(0.3795)
#
# _______________________
# epoch 3000
# Loss tensor(0.3763)
#
# _______________________
# epoch 3100
# Loss tensor(0.3731)
#
# _______________________
# epoch 3200
# Loss tensor(0.3703)
#
# _______________________
# epoch 3300
# Loss tensor(0.3679)
#
# _______________________
# epoch 3400
# Loss tensor(0.3658)
#
# _______________________
# epoch 3500
# Loss tensor(0.3638)
#
# _______________________
# epoch 3600
# Loss tensor(0.3620)
#
# _______________________
# epoch 3700
# Loss tensor(0.3599)
#
# _______________________
# epoch 3800
# Loss tensor(0.3561)
#
# _______________________
# epoch 3900
# Loss tensor(0.3540)
#
# _______________________
# epoch 4000
# Loss tensor(0.3524)
#
# _______________________
# epoch 4100
# Loss tensor(0.3511)
#
# _______________________
# epoch 4200
# Loss tensor(0.3500)
#
# _______________________
# epoch 4300
# Loss tensor(0.3489)
#
# _______________________
# epoch 4400
# Loss tensor(0.3480)
#
# _______________________
# epoch 4500
# Loss tensor(0.3470)
#
# _______________________
# epoch 4600
# Loss tensor(0.3461)
#
# _______________________
# epoch 4700
# Loss tensor(0.3453)
#
# _______________________
# epoch 4800
# Loss tensor(0.3446)
#
# _______________________
# epoch 4900
# Loss tensor(0.3439)
#
# _______________________
# epoch 5000
# Loss tensor(0.3433)
#
# _______________________
# epoch 5100
# Loss tensor(0.3428)
#
# _______________________
# epoch 5200
# Loss tensor(0.3423)
#
# _______________________
# epoch 5300
# Loss tensor(0.3418)
#
# _______________________
# epoch 5400
# Loss tensor(0.3414)
#
# _______________________
# epoch 5500
# Loss tensor(0.3409)
#
# _______________________
# epoch 5600
# Loss tensor(0.3405)
#
# _______________________
# epoch 5700
# Loss tensor(0.3401)
#
# _______________________
# epoch 5800
# Loss tensor(0.3397)
#
# _______________________
# epoch 5900
# Loss tensor(0.3393)
#
# _______________________
# epoch 6000
# Loss tensor(0.3390)
#
# _______________________
# epoch 6100
# Loss tensor(0.3386)
#
# _______________________
# epoch 6200
# Loss tensor(0.3383)
#
# _______________________
# epoch 6300
# Loss tensor(0.3380)
#
# _______________________
# epoch 6400
# Loss tensor(0.3377)
#
# _______________________
# epoch 6500
# Loss tensor(0.3374)
#
# _______________________
# epoch 6600
# Loss tensor(0.3371)
#
# _______________________
# epoch 6700
# Loss tensor(0.3369)
#
# _______________________
# epoch 6800
# Loss tensor(0.3367)
#
# _______________________
# epoch 6900
# Loss tensor(0.3364)
#
# _______________________
# epoch 7000
# Loss tensor(0.3362)
#
# _______________________
# epoch 7100
# Loss tensor(0.3360)
#
# _______________________
# epoch 7200
# Loss tensor(0.3358)
#
# _______________________
# epoch 7300
# Loss tensor(0.3357)
#
# _______________________
# epoch 7400
# Loss tensor(0.3355)
#
# _______________________
# epoch 7500
# Loss tensor(0.3353)
#
# _______________________
# epoch 7600
# Loss tensor(0.3352)
#
# _______________________
# epoch 7700
# Loss tensor(0.3350)
#
# _______________________
# epoch 7800
# Loss tensor(0.3349)
#
# _______________________
# epoch 7900
# Loss tensor(0.3347)
#
# _______________________
# epoch 8000
# Loss tensor(0.3346)
#
# _______________________
# epoch 8100
# Loss tensor(0.3344)
#
# _______________________
# epoch 8200
# Loss tensor(0.3343)
#
# _______________________
# epoch 8300
# Loss tensor(0.3342)
#
# _______________________
# epoch 8400
# Loss tensor(0.3341)
#
# _______________________
# epoch 8500
# Loss tensor(0.3340)
#
# _______________________
# epoch 8600
# Loss tensor(0.3339)
#
# _______________________
# epoch 8700
# Loss tensor(0.3338)
#
# _______________________
# epoch 8800
# Loss tensor(0.3336)
#
# _______________________
# epoch 8900
# Loss tensor(0.3335)
#
# _______________________
# epoch 9000
# Loss tensor(0.3335)
#
# _______________________
# epoch 9100
# Loss tensor(0.3334)
#
# _______________________
# epoch 9200
# Loss tensor(0.3333)
#
# _______________________
# epoch 9300
# Loss tensor(0.3332)
#
# _______________________
# epoch 9400
# Loss tensor(0.3331)
#
# _______________________
# epoch 9500
# Loss tensor(0.3330)
#
# _______________________
# epoch 9600
# Loss tensor(0.3329)
#
# _______________________
# epoch 9700
# Loss tensor(0.3329)
#
# _______________________
# epoch 9800
# Loss tensor(0.3328)
#
# _______________________
# epoch 9900
# Loss tensor(0.3327)
#
# _______________________
# epoch 10000
# Loss tensor(0.3326)
#
# _______________________
# epoch 10100
# Loss tensor(0.3325)
#
# _______________________
# epoch 10200
# Loss tensor(0.3325)
#
# _______________________
# epoch 10300
# Loss tensor(0.3324)
#
# _______________________
# epoch 10400
# Loss tensor(0.3323)
#
# _______________________
# epoch 10500
# Loss tensor(0.3322)
#
# _______________________
# epoch 10600
# Loss tensor(0.3322)
#
# _______________________
# epoch 10700
# Loss tensor(0.3321)
#
# _______________________
# epoch 10800
# Loss tensor(0.3320)
#
# _______________________
# epoch 10900
# Loss tensor(0.3320)
#
# _______________________
# epoch 11000
# Loss tensor(0.3319)
#
# _______________________
# epoch 11100
# Loss tensor(0.3319)
#
# _______________________
# epoch 11200
# Loss tensor(0.3318)
#
# _______________________
# epoch 11300
# Loss tensor(0.3318)
#
# _______________________
# epoch 11400
# Loss tensor(0.3317)
#
# _______________________
# epoch 11500
# Loss tensor(0.3317)
#
# _______________________
# epoch 11600
# Loss tensor(0.3316)
#
# _______________________
# epoch 11700
# Loss tensor(0.3316)
#
# _______________________
# epoch 11800
# Loss tensor(0.3316)
#
# _______________________
# epoch 11900
# Loss tensor(0.3315)
#
# _______________________
# epoch 12000
# Loss tensor(0.3315)
#
# _______________________
# epoch 12100
# Loss tensor(0.3315)
#
# _______________________
# epoch 12200
# Loss tensor(0.3314)
#
# _______________________
# epoch 12300
# Loss tensor(0.3314)
#
# _______________________
# epoch 12400
# Loss tensor(0.3314)
#
# _______________________
# epoch 12500
# Loss tensor(0.3314)
#
# _______________________
# epoch 12600
# Loss tensor(0.3313)
#
# _______________________
# epoch 12700
# Loss tensor(0.3313)
#
# _______________________
# epoch 12800
# Loss tensor(0.3313)
#
# _______________________
# epoch 12900
# Loss tensor(0.3313)
#
# _______________________
# epoch 13000
# Loss tensor(0.3312)
#
# _______________________
# epoch 13100
# Loss tensor(0.3312)
#
# _______________________
# epoch 13200
# Loss tensor(0.3312)
#
# _______________________
# epoch 13300
# Loss tensor(0.3312)
#
# _______________________
# epoch 13400
# Loss tensor(0.3312)
#
# _______________________
# epoch 13500
# Loss tensor(0.3312)
#
# _______________________
# epoch 13600
# Loss tensor(0.3311)
#
# _______________________
# epoch 13700
# Loss tensor(0.3311)
#
# _______________________
# epoch 13800
# Loss tensor(0.3311)
#
# _______________________
# epoch 13900
# Loss tensor(0.3311)
#
# _______________________
# epoch 14000
# Loss tensor(0.3311)
#
# _______________________
# epoch 14100
# Loss tensor(0.3311)
#
# _______________________
# epoch 14200
# Loss tensor(0.3311)
#
# _______________________
# epoch 14300
# Loss tensor(0.3310)
#
# _______________________
# epoch 14400
# Loss tensor(0.3310)
#
# _______________________
# epoch 14500
# Loss tensor(0.3310)
# _______________________
# epoch 14600
# Loss tensor(0.3310)
#
# _______________________
# epoch 14700
# Loss tensor(0.3310)
#
# _______________________
# epoch 14800
# Loss tensor(0.3310)
#
# _______________________
# epoch 14900
# Loss tensor(0.3310)
#
# _______________________
# epoch 15000
# Loss tensor(0.3310)
#
# _______________________
# epoch 15100
# Loss tensor(0.3310)
#
# _______________________
# epoch 15200
# Loss tensor(0.3310)
#
# _______________________
# epoch 15300
# Loss tensor(0.3309)
#
# _______________________
# epoch 15400
# Loss tensor(0.3309)
#
# _______________________
# epoch 15500
# Loss tensor(0.3309)
#
# _______________________
# epoch 15600
# Loss tensor(0.3309)
#
# _______________________
# epoch 15700
# Loss tensor(0.3309)
#
# _______________________
# epoch 15800
# Loss tensor(0.3309)
#
# _______________________
# epoch 15900
# Loss tensor(0.3309)
#
# _______________________
# epoch 16000
# Loss tensor(0.3309)
#
# _______________________
# epoch 16100
# Loss tensor(0.3309)
#
# _______________________
# epoch 16200
# Loss tensor(0.3309)
#
# _______________________
# epoch 16300
# Loss tensor(0.3309)
#
# _______________________
# epoch 16400
# Loss tensor(0.3309)
#
# _______________________
# epoch 16500
# Loss tensor(0.3309)
#
# _______________________
# epoch 16600
# Loss tensor(0.3309)
#
# _______________________
# epoch 16700
# Loss tensor(0.3309)
#
# _______________________
# epoch 16800
# Loss tensor(0.3309)
#
# _______________________
# epoch 16900
# Loss tensor(0.3309)
#
# _______________________
# epoch 17000
# Loss tensor(0.3309)
#
# _______________________
# epoch 17100
# Loss tensor(0.3309)
#
# _______________________
# epoch 17200
# Loss tensor(0.3308)
#
# _______________________
# epoch 17300
# Loss tensor(0.3308)
#
# _______________________
# epoch 17400
# Loss tensor(0.3308)
#
# _______________________
# epoch 17500
# Loss tensor(0.3308)
#
# _______________________
# epoch 17600
# Loss tensor(0.3308)
#
# _______________________
# epoch 17700
# Loss tensor(0.3308)
#
# _______________________
# epoch 17800
# Loss tensor(0.3308)
#
# _______________________
# epoch 17900
# Loss tensor(0.3308)
#
# _______________________
# epoch 18000
# Loss tensor(0.3308)
#
# _______________________
# epoch 18100
# Loss tensor(0.3308)
#
# _______________________
# epoch 18200
# Loss tensor(0.3308)
#
# _______________________
# epoch 18300
# Loss tensor(0.3308)
#
# _______________________
# epoch 18400
# Loss tensor(0.3308)
#
# _______________________
# epoch 18500
# Loss tensor(0.3308)
#
# _______________________
# epoch 18600
# Loss tensor(0.3308)
#
# _______________________
# epoch 18700
# Loss tensor(0.3308)
#
# _______________________
# epoch 18800
# Loss tensor(0.3308)
#
# _______________________
# epoch 18900
# Loss tensor(0.3308)
#
# _______________________
# epoch 19000
# Loss tensor(0.3308)
#
# _______________________
# epoch 19100
# Loss tensor(0.3308)
#
# _______________________
# epoch 19200
# Loss tensor(0.3308)
#
# _______________________
# epoch 19300
# Loss tensor(0.3308)
#
# _______________________
# epoch 19400
# Loss tensor(0.3308)
#
# _______________________
# epoch 19500
# Loss tensor(0.3308)
#
# _______________________
# epoch 19600
# Loss tensor(0.3308)
#
# _______________________
# epoch 19700
# Loss tensor(0.3308)
#
# _______________________
# epoch 19800
# Loss tensor(0.3308)
#
# _______________________
# epoch 19900
# Loss tensor(0.3308)
#
# _______________________
# epoch 20000
# Loss tensor(0.3308)
#
# _______________________
# epoch 20100
# Loss tensor(0.3308)
#
# _______________________
# epoch 20200
# Loss tensor(0.3308)
#
# _______________________
# epoch 20300
# Loss tensor(0.3308)
#
# _______________________
# epoch 20400
# Loss tensor(0.3308)
#
# _______________________
# epoch 20500
# Loss tensor(0.3308)
#
# _______________________
# epoch 20600
# Loss tensor(0.3308)
#
# _______________________
# epoch 20700
# Loss tensor(0.3308)
#
# _______________________
# epoch 20800
# Loss tensor(0.3308)
#
# _______________________
# epoch 20900
# Loss tensor(0.3308)
#
# _______________________
# epoch 21000
# Loss tensor(0.3308)
#
# _______________________
# epoch 21100
# Loss tensor(0.3308)
#
# _______________________
# epoch 21200
# Loss tensor(0.3308)
#
# _______________________
# epoch 21300
# Loss tensor(0.3308)
#
# _______________________
# epoch 21400
# Loss tensor(0.3308)
#
# _______________________
# epoch 21500
# Loss tensor(0.3308)
#
# _______________________
# epoch 21600
# Loss tensor(0.3308)
#
# _______________________
# epoch 21700
# Loss tensor(0.3308)
#
# _______________________
# epoch 21800
# Loss tensor(0.3308)
#
# _______________________
# epoch 21900
# Loss tensor(0.3308)
#
# _______________________
# epoch 22000
# Loss tensor(0.3308)
#
# _______________________
# epoch 22100
# Loss tensor(0.3308)
#
# _______________________
# epoch 22200
# Loss tensor(0.3308)
#
# _______________________
# epoch 22300
# Loss tensor(0.3308)
#
# _______________________
# epoch 22400
# Loss tensor(0.3308)
#
# _______________________
# epoch 22500
# Loss tensor(0.3308)
#
# _______________________
# epoch 22600
# Loss tensor(0.3308)
#
# _______________________
# epoch 22700
# Loss tensor(0.3308)
#
# _______________________
# epoch 22800
# Loss tensor(0.3308)
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-11-66385a4be245> in <module>()
#      28         ax.clear()
#      29         plt.scatter(x[:,0], x[:, 1], c=out.data.numpy().reshape(-1))
# ---> 30         fig.canvas.draw()
#      31         plt.pause(0.01)
#      32         print()
#
# ~/Program_Files/miniconda/lib/python3.7/site-packages/matplotlib/backends/backend_tkagg.py in draw(self)
#       8     def draw(self):
#       9         super(FigureCanvasTkAgg, self).draw()
# ---> 10         _backend_tk.blit(self._tkphoto, self.renderer._renderer, (0, 1, 2, 3))
#      11         self._master.update_idletasks()
#      12
#
# ~/Program_Files/miniconda/lib/python3.7/site-packages/matplotlib/backends/_backend_tk.py in blit(photoimage, aggimage, offsets, bbox)
#      78         bboxptr = (x1, x2, y1, y2)
#      79     else:
# ---> 80         photoimage.blank()
#      81         bboxptr = (0, width, 0, height)
#      82     _tkagg.blit(
#
# ~/Program_Files/miniconda/lib/python3.7/tkinter/__init__.py in blank(self)
#    3546     def blank(self):
#    3547         """Display a transparent image."""
# -> 3548         self.tk.call(self.name, 'blank')
#    3549     def cget(self, option):
#    3550         """Return the value of OPTION."""
#
# TclError: invalid command name "pyimage58"

# %%
# %matplotlib inline
plt.scatter(x[:,0], x[:, 1], c=out.data.numpy().reshape(-1))

# %%
h = 0.01
x_, y_ = np.meshgrid(np.arange(x[:,0].min(), x[:,0].max(), h), np.arange(x[:,1].min(), x[:,1].max(), h))
xx_img = np.c_[x_.ravel(), y_.ravel()]
xx_img = torch.FloatTensor(xx_img)
yout_img = model(xx_img)
out = yout_img.data.numpy()
out = (out.argmax(axis=1)).astype(int)

colors = ['r', 'y', 'g', 'b']
plt.imshow(out.reshape(x_.shape), interpolation='nearest',
           extent=(x_.min(), x_.max(), y_.min(), y_.max()),
           cmap=matplotlib.colors.ListedColormap(colors[1:-1]),
           alpha=0.5,
           aspect='auto', origin='lower')

plt.scatter(x[:,0], x[:, 1], c=y.reshape(-1), marker='*')

# %%
# ##### For probabilistic network only
# p = model.pl1.actf(model.pl1.fcp(xx))
# r = model.pl1.fcr(xx)
# out = model(xx)

# plt.scatter(x[:,0], x[:, 1], c=yout.data.numpy().reshape(-1)) 
# for prb in p.data.numpy().T:
#     plt.scatter(x[:,0], prb, marker='.', c='y')
