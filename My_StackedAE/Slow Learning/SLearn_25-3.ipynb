# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
# %matplotlib inline
from tensorflow.examples.tutorials.mnist import input_data

# %%
mnist = input_data.read_data_sets("../../Tensorflow-Bootcamp-master/03-Convolutional-Neural-Networks/MNIST_data/",one_hot=True)
# Out:
# Extracting ../../Tensorflow-Bootcamp-master/03-Convolutional-Neural-Networks/MNIST_data/train-images-idx3-ubyte.gz
# Extracting ../../Tensorflow-Bootcamp-master/03-Convolutional-Neural-Networks/MNIST_data/train-labels-idx1-ubyte.gz
# Extracting ../../Tensorflow-Bootcamp-master/03-Convolutional-Neural-Networks/MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting ../../Tensorflow-Bootcamp-master/03-Convolutional-Neural-Networks/MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
tf.reset_default_graph()

# %%
# DEFINE parameters
num_label = 10
label_hid1 = 5
label_hid2 = 3
label_hid3 = 2
label_hid4 = 1

num_image = 784 # 28*28
image_hid1 = 392
image_hid2 = 196
image_hid3 = 98
image_hid4 = 49
image_hid5 = 25
image_hid6 = 12
image_hid7 = 6
image_hid8 = 3
image_hid9 = 2
image_hid10 = 1

# %%
tie_weight = tf.transpose
act_func = lambda X:X
initializer = tf.variance_scaling_initializer()

# %%
## PLACEHOLDER DEFINATION
X = tf.placeholder(tf.float32, shape=[None, num_image])
Y = tf.placeholder(tf.float32, shape=[None, num_label])

# %% [markdown]
# ## Loading Encoded Model

# %%
## IMAGE COMPRESSION
wi1 = tf.Variable(np.load('../save/weights/w1.npy'))
wi2 = tf.Variable(np.load('../save/weights/w2.npy'))
wi3 = tf.Variable(np.load('../save/weights/w3.npy'))
wi4 = tf.Variable(np.load('../save/weights/w4.npy'))
wi5 = tf.Variable(np.load('../save/weights/w5.npy'))
wi6 = tf.Variable(np.load('../save/weights/w6.npy'))
wi7 = tf.Variable(np.load('../save/weights/w7.npy'))
wi8 = tf.Variable(np.load('../save/weights/w8.npy'))
wi9 = tf.Variable(np.load('../save/weights/w9.npy'))
wi10 = tf.Variable(np.load('../save/weights/w10.npy'))

# %%
img_layer1 = act_func(tf.matmul(X, wi1))
img_layer2 = act_func(tf.matmul(img_layer1, wi2))
img_layer3 = act_func(tf.matmul(img_layer2, wi3))
img_layer4 = act_func(tf.matmul(img_layer3, wi4))
img_layer5 = act_func(tf.matmul(img_layer4, wi5))
img_layer6 = act_func(tf.matmul(img_layer5, wi6))
img_layer7 = act_func(tf.matmul(img_layer6, wi7))
img_layer8 = act_func(tf.matmul(img_layer7, wi8))
img_layer9 = act_func(tf.matmul(img_layer8, wi9))
img_layer10 = act_func(tf.matmul(img_layer9, wi10))

# %%
## LABEL DECOMPRESSION
wl1 = tf.Variable(np.load('../save/weights/lw1.npy'))
wl2 = tf.Variable(np.load('../save/weights/lw2.npy'))
wl3 = tf.Variable(np.load('../save/weights/lw3.npy'))
wl4 = tf.Variable(np.load('../save/weights/lw4.npy'))

# %%
lbl_layer1 = act_func(tf.matmul(Y, wl1))
lbl_layer2 = act_func(tf.matmul(lbl_layer1, wl2))
lbl_layer3 = act_func(tf.matmul(lbl_layer2, wl3))
lbl_layer4 = act_func(tf.matmul(lbl_layer3, wl4))

# %% [markdown]
# ## Setting up learning Model

# %%
# Learning Parameters for activation learning
initializer = tf.random_uniform_initializer()

# input_no = image_hid8
# output_no = label_hid3

inpt = img_layer5
yval = lbl_layer2

i=12
j=3

pW1 = tf.Variable(np.load('../save/weights/slearn_parms0_{}-{}.npy'.format(i, j)))
W1 = tf.Variable(tf.matmul(wi6,pW1))
W2 = tf.Variable(np.load('../save/weights/slearn_parms1_{}-{}.npy'.format(i, j)))
W3 = tf.Variable(np.load('../save/weights/slearn_parms2_{}-{}.npy'.format(i, j)))
# W3 = tf.Variable(tf.matmul(pW3, tf.transpose(wl3)))

b1 = tf.Variable(np.load('../save/weights/slearn_parms3_{}-{}.npy'.format(i, j)))
b2 = tf.Variable(np.load('../save/weights/slearn_parms4_{}-{}.npy'.format(i, j)))
b3 = tf.Variable(np.load('../save/weights/slearn_parms5_{}-{}.npy'.format(i, j)))
# b3 = tf.Variable(tf.matmul(pb3,tf.transpose(wl3)))

a1 = tf.nn.relu(tf.matmul(inpt, W1) + b1)
a2 = tf.nn.relu(tf.matmul(a1, W2) + b2)
a3 = tf.matmul(a2, W3) + b3

output = a3

# %%
print(W1)
print(b3)
# Out:
# <tf.Variable 'Variable_22:0' shape=(25, 155) dtype=float32_ref>
# <tf.Variable 'Variable_27:0' shape=(1, 3) dtype=float32_ref>

# %% [markdown]
# ## Create Encode-Decode Model

# %%
# out_layer1 = tf.matmul(output,tf.transpose(wl4))
# out_layer2 = tf.matmul(output,tf.transpose(wl3))
out_layer3 = tf.matmul(output,tf.transpose(wl2))
out_layer4 = tf.matmul(out_layer3,tf.transpose(wl1))

# %%
# LOSS FUNCTIONS
loss = tf.reduce_mean(tf.square(output - yval))
# loss = tf.reduce_mean(tf.abs(output_layer - X))
# cross_entropy = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=Y,logits=yout))

# %%
# TRAINING
learning_rate = 0.001
optimizer = tf.train.AdamOptimizer(learning_rate)
train = optimizer.minimize(loss, var_list=[W1, W2, W3, b1, b2, b3])

# %%
# PREPARATION
init = tf.global_variables_initializer()
saver = tf.train.Saver()

# %%
num_epochs = 100
batch_size = 50

try:
    with tf.Session() as sess:
        sess.run(init)

        # Epoch == Entire Training Set
        for epoch in range(num_epochs):
            num_batches = mnist.train.num_examples // batch_size

            # 150 batch size
            for iteration in range(num_batches):
                X_batch, y_batch = mnist.train.next_batch(batch_size+3*epoch)
                sess.run(train, feed_dict={X: X_batch, Y: y_batch})

            training_loss = loss.eval(feed_dict={X: X_batch, Y: y_batch})   
            print("Epoch {} Complete. Training Loss: {}".format(epoch,training_loss))
            saver.save(sess, "../save/slearn_25-3.ckpt")
            
            matches = tf.equal(tf.argmax(out_layer4, 1), tf.argmax(Y,1))
            acc = tf.reduce_mean(tf.cast(matches, tf.float32))

            print('TEST ACCURACY: ')
            print (sess.run(acc, feed_dict={X:mnist.test.images, Y:mnist.test.labels}))
            if epoch % 5 == 0:
                print('TRAIN ACCURACY: ')
                print (sess.run(acc, feed_dict={X:mnist.train.images, Y:mnist.train.labels}))
            print()
            
except KeyboardInterrupt:
    print('Keyboard Interrupted')
finally:
    print('Finished Training the Model')
# Out:
# Epoch 0 Complete. Training Loss: 1.4452450275421143
# TEST ACCURACY:
# 0.9098
# TRAIN ACCURACY:
# 0.91123635
#
# Epoch 1 Complete. Training Loss: 1.2731819152832031
# TEST ACCURACY:
# 0.9157
#
# Epoch 2 Complete. Training Loss: 0.824313759803772
# TEST ACCURACY:
# 0.9163
#
# Epoch 3 Complete. Training Loss: 0.664046049118042
# TEST ACCURACY:
# 0.9213
#
# Epoch 4 Complete. Training Loss: 1.5290958881378174
# TEST ACCURACY:
# 0.921
#
# Epoch 5 Complete. Training Loss: 0.9904430508613586
# TEST ACCURACY:
# 0.9207
# TRAIN ACCURACY:
# 0.9256909
#
# Epoch 6 Complete. Training Loss: 0.7697773575782776
# TEST ACCURACY:
# 0.9216
#
# Epoch 7 Complete. Training Loss: 0.8131217956542969
# TEST ACCURACY:
# 0.9217
#
# Epoch 8 Complete. Training Loss: 1.423171043395996
# TEST ACCURACY:
# 0.9241
#
# Epoch 9 Complete. Training Loss: 1.6311299800872803
# TEST ACCURACY:
# 0.9238
#
# Epoch 10 Complete. Training Loss: 1.4717267751693726
# TEST ACCURACY:
# 0.9252
# TRAIN ACCURACY:
# 0.93154544
#
# Epoch 11 Complete. Training Loss: 1.539237380027771
# TEST ACCURACY:
# 0.9237
#
# Epoch 12 Complete. Training Loss: 0.8440801501274109
# TEST ACCURACY:
# 0.9261
#
# Epoch 13 Complete. Training Loss: 0.6311735510826111
# TEST ACCURACY:
# 0.9257
#
# Epoch 14 Complete. Training Loss: 1.4815685749053955
# TEST ACCURACY:
# 0.9263
#
# Epoch 15 Complete. Training Loss: 0.8575299978256226
# TEST ACCURACY:
# 0.9262
# TRAIN ACCURACY:
# 0.93334544
#
# Epoch 16 Complete. Training Loss: 1.1688414812088013
# TEST ACCURACY:
# 0.9283
#
# Epoch 17 Complete. Training Loss: 1.252372145652771
# TEST ACCURACY:
# 0.9282
#
# Epoch 18 Complete. Training Loss: 0.9893674850463867
# TEST ACCURACY:
# 0.9261
#
# Epoch 19 Complete. Training Loss: 0.8938362002372742
# TEST ACCURACY:
# 0.9285
#
# Epoch 20 Complete. Training Loss: 0.7214573621749878
# TEST ACCURACY:
# 0.9281
# TRAIN ACCURACY:
# 0.9369091
#
# Epoch 21 Complete. Training Loss: 1.0645383596420288
# TEST ACCURACY:
# 0.9273
#
# Epoch 22 Complete. Training Loss: 0.6735206842422485
# TEST ACCURACY:
# 0.9305
#
# Epoch 23 Complete. Training Loss: 1.0383782386779785
# TEST ACCURACY:
# 0.9312
#
# Epoch 24 Complete. Training Loss: 0.7399754524230957
# TEST ACCURACY:
# 0.93
#
# Epoch 25 Complete. Training Loss: 0.824923574924469
# TEST ACCURACY:
# 0.929
# TRAIN ACCURACY:
# 0.9375091
#
# Epoch 26 Complete. Training Loss: 0.6223219633102417
# TEST ACCURACY:
# 0.9304
#
# Epoch 27 Complete. Training Loss: 0.8079640865325928
# TEST ACCURACY:
# 0.9314
#
# Epoch 28 Complete. Training Loss: 0.9954124093055725
# TEST ACCURACY:
# 0.929
#
# Epoch 29 Complete. Training Loss: 0.6531170606613159
# TEST ACCURACY:
# 0.9313
#
# Epoch 30 Complete. Training Loss: 0.8261734247207642
# TEST ACCURACY:
# 0.9306
# TRAIN ACCURACY:
# 0.9400182
#
# Epoch 31 Complete. Training Loss: 1.073129415512085
# TEST ACCURACY:
# 0.9319
#
# Epoch 32 Complete. Training Loss: 0.7035130858421326
# TEST ACCURACY:
# 0.9296
#
# Epoch 33 Complete. Training Loss: 0.8705665469169617
# TEST ACCURACY:
# 0.9322
#
# Epoch 34 Complete. Training Loss: 1.050662875175476
# TEST ACCURACY:
# 0.9318
#
# Epoch 35 Complete. Training Loss: 0.6332995295524597
# TEST ACCURACY:
# 0.9307
# TRAIN ACCURACY:
# 0.9402364
#
# Epoch 36 Complete. Training Loss: 0.9008162617683411
# TEST ACCURACY:
# 0.9311
#
# Epoch 37 Complete. Training Loss: 1.1081807613372803
# TEST ACCURACY:
# 0.932
#
# Epoch 38 Complete. Training Loss: 0.9694886803627014
# TEST ACCURACY:
# 0.9317
#
# Epoch 39 Complete. Training Loss: 0.7908962965011597
# TEST ACCURACY:
# 0.9325
#
# Epoch 40 Complete. Training Loss: 0.8083219528198242
# TEST ACCURACY:
# 0.9327
# TRAIN ACCURACY:
# 0.94183636
#
# Epoch 41 Complete. Training Loss: 0.9691657423973083
# TEST ACCURACY:
# 0.9332
#
# Epoch 42 Complete. Training Loss: 1.2302885055541992
# TEST ACCURACY:
# 0.9331
#
# Epoch 43 Complete. Training Loss: 1.1243480443954468
# TEST ACCURACY:
# 0.932
#
# Epoch 44 Complete. Training Loss: 0.7209122776985168
# TEST ACCURACY:
# 0.9344
#
# Epoch 45 Complete. Training Loss: 0.8823970556259155
# TEST ACCURACY:
# 0.9334
# TRAIN ACCURACY:
# 0.9418
#
# Epoch 46 Complete. Training Loss: 0.8665726780891418
# TEST ACCURACY:
# 0.9334
#
# Epoch 47 Complete. Training Loss: 0.8835273385047913
# TEST ACCURACY:
# 0.9345
#
# Epoch 48 Complete. Training Loss: 0.7328945398330688
# TEST ACCURACY:
# 0.9334
#
# Epoch 49 Complete. Training Loss: 0.8107673525810242
# TEST ACCURACY:
# 0.9347
#
# Epoch 50 Complete. Training Loss: 0.8036673069000244
# TEST ACCURACY:
# 0.9336
# TRAIN ACCURACY:
# 0.9409091
#
# Epoch 51 Complete. Training Loss: 0.923607349395752
# TEST ACCURACY:
# 0.9336
#
# Keyboard Interrupted
# Finished Training the Model

# %%
num_test_labels = 10
start_point = 15
with tf.Session() as sess:
    
#     sess.run(init)
    saver.restore(sess,"../save/slearn_25-3.ckpt")
    
    params = sess.run([W1, W2, W3, b1, b2, b3])
    
    matches = tf.equal(tf.argmax(out_layer4, 1), tf.argmax(Y,1))
    acc = tf.reduce_mean(tf.cast(matches, tf.float32))
    
    print('TRAIN ACCURACY: ')
    print (sess.run(acc, feed_dict={X:mnist.train.images, Y:mnist.train.labels}))

    print('TEST ACCURACY: ')
    print (sess.run(acc, feed_dict={X:mnist.test.images, Y:mnist.test.labels}))
    print('\n')
# Out:
# INFO:tensorflow:Restoring parameters from ../save/slearn_25-3.ckpt
# TRAIN ACCURACY:
# 0.94305456
# TEST ACCURACY:
# 0.9336

# %%
params
# Out:
# [array([[ 0.09561947,  0.10627775,  0.05130621, ...,  0.39042687,
#           0.03350773,  0.10889429],
#         [-0.15922114, -0.17696883, -0.08543275, ...,  0.35434797,
#          -0.05579554, -0.1813258 ],
#         [ 0.00182906,  0.00203293,  0.00098141, ...,  0.39544842,
#           0.00064096,  0.002083  ],
#         ...,
#         [-0.02339784, -0.02600591, -0.0125545 , ...,  0.25598145,
#          -0.00819926, -0.02664616],
#         [-0.14006475, -0.15567715, -0.07515407, ..., -0.08737056,
#          -0.04908261, -0.15950991],
#         [ 0.0566354 ,  0.0629483 ,  0.03038866, ...,  0.33049423,
#           0.01984662,  0.06449807]], dtype=float32),
#  array([[ 0.12928236,  0.00709345,  0.2270143 , ..., -0.11943059,
#           0.70338863,  0.65438473],
#         [ 0.5483187 ,  0.02092948,  0.75045013, ...,  0.6519301 ,
#           0.2481015 , -0.07473479],
#         [ 0.6927793 ,  0.39143902,  0.849975  , ..., -0.02917881,
#           0.7804612 ,  0.8315323 ],
#         ...,
#         [ 1.0386493 , -0.25125316,  0.40755937, ...,  0.79146355,
#           0.40091237, -0.3354249 ],
#         [ 0.40146548,  0.82552207,  0.22120453, ...,  0.37094074,
#           0.6960912 ,  0.29183385],
#         [ 0.7315277 ,  0.3760425 ,  0.20362827, ...,  0.39146245,
#           0.6885634 ,  0.46912655]], dtype=float32),
#  array([[ 0.19753604,  0.1143011 ,  1.4766893 ],
#         [-1.5260268 ,  0.30415836,  1.0945514 ],
#         [ 0.38717684,  1.2409703 ,  0.5433234 ],
#         [-0.08575147,  0.6728441 ,  0.8422829 ],
#         [ 0.01793879, -0.61847514, -0.70660836],
#         [ 1.0389886 , -1.9826481 , -1.5609113 ],
#         [ 0.58831525, -1.3542958 , -0.8741821 ],
#         [ 1.7662073 , -2.6433742 ,  1.8393972 ],
#         [-1.1122429 , -0.21443671, -2.7633953 ],
#         [-1.8021775 , -0.686035  , -1.679233  ],
#         [-0.8392753 ,  0.20922145,  0.40615553],
#         [ 0.32339987,  1.0086173 ,  0.9400615 ],
#         [-0.00814852,  0.80746   ,  0.5331498 ],
#         [-1.2063808 ,  1.1666172 ,  1.1778483 ],
#         [-0.17429829,  1.2969302 ,  0.32582694],
#         [ 0.9526543 ,  0.35902697, -0.19464348],
#         [ 1.6298226 ,  0.8080377 ,  1.8681581 ],
#         [ 0.04086301,  0.4584142 ,  0.25134894],
#         [ 0.16025862,  1.0762722 ,  0.38273862],
#         [-0.6398955 ,  0.93462527, -0.347715  ],
#         [-0.3409591 , -1.9239393 , -2.0484004 ],
#         [-0.7039014 ,  2.7759657 ,  0.18991885],
#         [ 0.35081485, -0.7781586 , -1.8410356 ],
#         [ 0.7558853 , -1.4404886 , -0.8702801 ],
#         [ 0.2796993 ,  0.629529  ,  0.17585911],
#         [ 0.5972686 ,  0.80200595,  1.2876103 ],
#         [ 0.95993775, -0.38017824, -1.2916695 ],
#         [-0.3138465 ,  1.2516211 ,  1.0494751 ],
#         [-1.5202167 ,  0.36877707,  1.3444409 ],
#         [ 0.08132187, -0.94039696, -1.5154121 ],
#         [-0.80167586, -0.03647879,  0.61770993]], dtype=float32),
#  array([-0.28383029, -0.31458557, -0.15186486,  0.8915307 , -0.26639026,
#          0.92948496,  0.7187679 , -0.03149702, -0.00305842, -0.4560608 ,
#          0.13541721, -0.21263544, -0.06160916, -0.31217527, -0.10744675,
#          1.5539243 , -0.12664579, -0.06842119, -0.04330331, -0.08283355,
#         -0.23805155, -0.1870908 , -0.23751526, -0.3471313 , -0.21489719,
#         -0.18942702, -0.22555311,  0.0643752 ,  0.05194964, -0.02596493,
#         -1.0687616 , -0.33435127, -0.15995553, -0.20170794, -0.14258547,
#         -0.01627403, -0.10622326, -0.08091658, -0.3327444 ,  0.04153078,
#         -0.06249094, -0.20345554, -0.00187809, -0.10168617, -0.10713416,
#         -0.32413107, -0.04729197, -0.11250894, -0.19976912, -0.28495467,
#         -0.17469911, -0.30920935,  0.47452247,  0.19737032, -0.13741975,
#         -0.07063854, -0.16984136, -0.18727449, -0.30248228, -0.58200055,
#         -0.23112178, -0.6498527 , -0.19898465, -0.23572895, -0.23653843,
#         -0.27749056, -0.33645573,  0.390424  , -0.31371927, -0.30730048,
#          0.03483503, -0.34579587, -0.23848681, -0.1865959 , -0.09067887,
#         -0.01844228, -0.18869911, -0.3785864 ,  0.29200387,  0.3844032 ,
#         -0.19297187, -0.13239871, -1.045961  , -0.19007044, -0.25604025,
#         -0.32444695, -0.2393859 , -0.16607864, -0.18790606, -0.24759218,
#         -0.01826485, -0.31940347, -0.25278816, -0.10948997, -0.18110532,
#         -0.17285003, -0.00264572, -0.14541171, -0.31624797, -0.06309664,
#         -0.00314215, -0.11497195, -0.06430664, -0.71701217, -0.17002307,
#          0.77806437,  0.5690825 , -0.26094735, -0.10315148, -0.06065961,
#         -0.36564913, -0.12804289, -0.17049542, -0.13507186, -0.13124591,
#         -0.47798997, -0.5953483 , -0.5253036 , -0.00500092, -0.18614395,
#         -0.25848284, -0.21713065, -0.4574812 ,  1.6464075 , -0.17476822,
#         -0.0395139 ,  0.04845734, -0.1089573 , -0.21143371, -0.23421483,
#         -0.15427087, -0.13839707,  0.13148999, -0.08271152, -0.04803753,
#         -0.02969478, -0.16844337, -0.12841488, -0.10630793, -0.30410913,
#         -0.20056294, -0.20006253, -0.18251912,  0.11210488, -0.15121455,
#         -0.30812535, -0.22134608, -0.21894099,  0.09483296, -0.31525296,
#         -0.08532681, -0.03395198,  0.31646228, -0.09930573, -0.32260868],
#        dtype=float32),
#  array([-0.31236732, -0.2690858 , -0.77250123,  0.6042903 ,  0.76511115,
#         -0.3997387 ,  1.4138682 , -0.996359  , -0.20967805, -1.1127788 ,
#          0.23497044, -0.13057202, -0.09587593,  0.5230763 , -0.23023102,
#          1.1043065 , -1.9943898 , -0.05096714, -0.47361284,  0.73558116,
#         -1.4788282 ,  0.1921967 , -1.9943441 ,  1.3156971 , -0.02792981,
#          0.53111786,  0.85574365, -1.2684995 ,  0.8355964 ,  0.11165481,
#          0.24705136], dtype=float32),
#  array([[ 0.11753422, -1.5726492 , -1.9514915 ]], dtype=float32)]

# %%
for i in range(len(params)):
    np.save('../save/weights/slearn_parms{}_25-3.npy'.format(i),params[i])
