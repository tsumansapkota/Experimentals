# %%
import numpy as np
import pandas as pd

# %%
elem = pd.read_csv('./element_data_2.csv')

# %%
elem = elem.drop(elem.index[-1])

# %%
elem
# Out:
#         SN symbol            name  atomicNumber  proton  neutron  mass_no  \
# 0      1.0     H         Hydrogen           1.0     1.0      0.0      1.0
# 1      2.0    He           Helium           2.0     2.0      2.0      4.0
# 2      3.0    Li          Lithium           3.0     3.0      4.0      7.0
# 3      4.0    Be        Beryllium           4.0     4.0      5.0      9.0
# 4      5.0     B            Boron           5.0     5.0      6.0     11.0
# 5      6.0     C           Carbon           6.0     6.0      6.0     12.0
# 6      7.0     N         Nitrogen           7.0     7.0      7.0     14.0
# 7      8.0     O           Oxygen           8.0     8.0      8.0     16.0
# 8      9.0     F         Fluorine           9.0     9.0     10.0     19.0
# 9     10.0    Ne             Neon          10.0    10.0     10.0     20.0
# 10    11.0    Na           Sodium          11.0    11.0     12.0     23.0
# 11    12.0    Mg        Magnesium          12.0    12.0     12.0     24.0
# ...

# %%
elem[['SN','atomicNumber','proton','neutron', 'mass_no']] = elem[['SN','atomicNumber','proton','neutron', 'mass_no']].astype(int)

# %%
elem
# Out:
#       SN symbol            name  atomicNumber  proton  neutron  mass_no  \
# 0      1     H         Hydrogen             1       1        0        1
# 1      2    He           Helium             2       2        2        4
# 2      3    Li          Lithium             3       3        4        7
# 3      4    Be        Beryllium             4       4        5        9
# 4      5     B            Boron             5       5        6       11
# 5      6     C           Carbon             6       6        6       12
# 6      7     N         Nitrogen             7       7        7       14
# 7      8     O           Oxygen             8       8        8       16
# 8      9     F         Fluorine             9       9       10       19
# 9     10    Ne             Neon            10      10       10       20
# 10    11    Na           Sodium            11      11       12       23
# 11    12    Mg        Magnesium            12      12       12       24
# ...

# %%
elem.to_csv('./clean_element.csv')
